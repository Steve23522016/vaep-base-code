# %%
from socceraction.data.wyscout import PublicWyscoutLoader
from socceraction.spadl.wyscout import convert_to_actions as convert_to_actions_wyscout
from socceraction.spadl.statsbomb import convert_to_actions as convert_to_actions_statsbomb
from socceraction.data.opta import OptaLoader
from socceraction.data.statsbomb import StatsBombLoader
from socceraction.spadl.config import actiontypes, bodyparts
import socceraction.spadl as spadl
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, roc_auc_score, brier_score_loss, log_loss, mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef, balanced_accuracy_score
from xgboost import XGBClassifier, XGBRegressor
from catboost import CatBoostClassifier
import math
import pickle
import os
from name_matching.name_matcher import NameMatcher
from rapidfuzz import fuzz
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.feature_selection import r_regression, SelectKBest, chi2, mutual_info_classif, SequentialFeatureSelector, RFECV, SelectFromModel, mutual_info_regression, f_regression
from scipy.stats import pearsonr, chisquare
from mrmr import mrmr_classif
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.svm import LinearSVR, SVC
from sklearn.linear_model import Lasso, LogisticRegression
import socceraction.vaep.labels as lab
import socceraction.vaep.features as fs
import socceraction.spadl as spadl
from datetime import timedelta
import socceraction.vaep.formula as vaepformula

# %%
api = StatsBombLoader(root="data/statsbomb", getter="local")

# %%
# Competition which has 360 files data (UEFA Euro 2020 (55, 43) and FIFA World Cup 2022 (43, 106))
MAPS_COMPETITION_CONTAINS_360_DATA = {
    (55, 43) : "UEFA Euro 2020",
    (43, 106) : "FIFA World Cup 2022"
}
MAPS_PLAYER_ID_WITH_VAEP_VALUE = {
    (55, 43) : {},
    (43, 106) : {}
}
POSSIBLE_SCENARIO_OPTION = ["best"]
MAPS_PROPOSED_PLAYER_RANKING_GENERATOR = {
    "xpass" : {
        "model_directory" : "data/model_xpass/",
        "type_ids_spadl" : [0,1],
        "action_name" : "pass"
    },
    "xgoal" : {
        "model_directory" : "data/model_xgoal/",
        "type_ids_spadl" : [11, 12, 13],
        "action_name" : "goal"
    },
    "xdribble" : {
        "model_directory" : "data/model_xdribble/",
        "type_ids_spadl" : [7, 21],
        "action_name" : "dribble"
    }
}
ALL_TYPE_IDS_FROM_MODELS = [0, 1, 11, 12, 13, 7, 21]
DIRECTORY_FINAL_PLAYERS_CSV_DATAS = "data/players_skill_dataset/final_players_skill_dataset.csv"
DIRECTORY_PLAYERS_DATA = "data/players_skill_dataset/"

# %%
# VAEP Processing Algorithm
def process_vaep_algorithm(spadl_game_df, referenced_team_id):
    # 1. convert actions to game states
    home_team_id = referenced_team_id
    gamestates = fs.gamestates(spadl_game_df, 3)
    gamestates = fs.play_left_to_right(gamestates, home_team_id)

    # 2. compute features
    xfns = [
        fs.actiontype, 
        fs.result, 
        fs.bodypart, 
        fs.time, 
        fs.startlocation, 
        fs.endlocation,
        fs.startpolar,
        fs.endpolar,
        fs.movement,
        fs.team,
        fs.time_delta,
        fs.space_delta,
        fs.goalscore
    ]
    X = pd.concat([fn(gamestates) for fn in xfns], axis=1)

    # 3. compute labels
    yfns = [lab.scores, lab.concedes]
    Y = pd.concat([fn(spadl_game_df) for fn in yfns], axis=1)

    # 4. load or train models
    Y_hat = pd.DataFrame()
    models = {}
    for col in list(Y.columns):
        model = XGBClassifier(objective="binary:logistic")
        model.fit(X, Y[col])
        models[col] = model

    # 5. predict scoring and conceding probabilities for each game state
    for col in list(Y.columns):
        Y_hat[col] = [p[1] for p in models[col].predict_proba(X)]
    
    # 6. compute VAEP value
    values = vaepformula.value(spadl_game_df, Y_hat["scores"], Y_hat["concedes"])
    
    return values['vaep_value']

# %%
def initialize_maps_player_id_with_vaep_value():
    for competition_id, season_id in list(MAPS_COMPETITION_CONTAINS_360_DATA.keys()):
        games_df = api.games(competition_id, season_id)
        for _, row in games_df.iterrows():
            players_df = api.players(row['game_id'])
            for _, row_player in players_df.iterrows():
                player_ids = list(MAPS_PLAYER_ID_WITH_VAEP_VALUE[(competition_id, season_id)].keys())
                if row_player['player_id'] not in player_ids:
                    MAPS_PLAYER_ID_WITH_VAEP_VALUE[(competition_id, season_id)][row_player['player_id']] = {
                        "num_minutes_played" : 0,
                        "total_vaep_value" : 0,
                        "total_contribution_score" : 0
                    }
                else:
                    MAPS_PLAYER_ID_WITH_VAEP_VALUE[(competition_id, season_id)] \
                        [row_player['player_id']]["num_minutes_played"] += row_player['minutes_played']

# %%
# COMMENT IT IF VAEP PLAYER RANKING ALREADY LOADED
initialize_maps_player_id_with_vaep_value()
for competition_id, season_id in list(MAPS_PLAYER_ID_WITH_VAEP_VALUE.keys()):
    print("Competition Name : ", MAPS_COMPETITION_CONTAINS_360_DATA[(competition_id, season_id)])
    for player_id in list(MAPS_PLAYER_ID_WITH_VAEP_VALUE[(competition_id, season_id)].keys()):
        print(f'Player ID : {player_id}')
        print(f'Num Minutes Played : {MAPS_PLAYER_ID_WITH_VAEP_VALUE[(competition_id, season_id)][player_id]["num_minutes_played"]}')
    print("=================================================================")
# Out:
# Competition Name :  UEFA Euro 2020
# Player ID : 3477
# Num Minutes Played : 413
# Player ID : 3957
# Num Minutes Played : 293
# Player ID : 4353
# Num Minutes Played : 541
# Player ID : 5199
# Num Minutes Played : 399
# Player ID : 5203
# Num Minutes Played : 289
# Player ID : 5208
# Num Minutes Played : 70
# Player ID : 5211
# Num Minutes Played : 463
# Player ID : 6685
# Num Minutes Played : 158
# Player ID : 6720
# Num Minutes Played : 227
# Player ID : 6748
# Num Minutes Played : 284
# Player ID : 6765
# Num Minutes Played : 236
# Player ID : 6766
# Num Minutes Played : 225
# Player ID : 6840
# Num Minutes Played : 230
# Player ID : 6892
# Num Minutes Played : 286
# Player ID : 11748
# Num Minutes Played : 541
# Player ID : 16532
# Num Minutes Played : 316
# Player ID : 30486
# Num Minutes Played : 541
# Player ID : 3533
# Num Minutes Played : 295
# Player ID : 5537
# Num Minutes Played : 181
# Player ID : 5538
# Num Minutes Played : 30
# Player ID : 5543
# Num Minutes Played : 308
# Player ID : 5544
# Num Minutes Played : 375
# Player ID : 5545
# Num Minutes Played : 360
# Player ID : 5548
# Num Minutes Played : 202
# Player ID : 5549
# Num Minutes Played : 414
# Player ID : 5550
# Num Minutes Played : 414
# Player ID : 5834
# Num Minutes Played : 134
# Player ID : 6983
# Num Minutes Played : 404
# Player ID : 7796
# Num Minutes Played : 203
# Player ID : 8814
# Num Minutes Played : 414
# Player ID : 16022
# Num Minutes Played : 47
# Player ID : 16026
# Num Minutes Played : 10
# Player ID : 16027
# Num Minutes Played : 211
# Player ID : 30401
# Num Minutes Played : 82
# Player ID : 3570
# Num Minutes Played : 519
# Player ID : 3815
# Num Minutes Played : 519
# Player ID : 3959
# Num Minutes Played : 451
# Player ID : 4447
# Num Minutes Played : 519
# Player ID : 5524
# Num Minutes Played : 269
# Player ID : 5527
# Num Minutes Played : 380
# Player ID : 5534
# Num Minutes Played : 467
# Player ID : 5536
# Num Minutes Played : 259
# Player ID : 5732
# Num Minutes Played : 71
# Player ID : 6302
# Num Minutes Played : 198
# Player ID : 6797
# Num Minutes Played : 229
# Player ID : 7097
# Num Minutes Played : 172
# Player ID : 8815
# Num Minutes Played : 424
# Player ID : 16554
# Num Minutes Played : 519
# Player ID : 18722
# Num Minutes Played : 174
# Player ID : 24443
# Num Minutes Played : 261
# Player ID : 5170
# Num Minutes Played : 120
# Player ID : 5171
# Num Minutes Played : 168
# Player ID : 5177
# Num Minutes Played : 197
# Player ID : 5179
# Num Minutes Played : 131
# Player ID : 5195
# Num Minutes Played : 185
# Player ID : 5677
# Num Minutes Played : 0
# Player ID : 6299
# Num Minutes Played : 119
# Player ID : 15545
# Num Minutes Played : 130
# Player ID : 16583
# Num Minutes Played : 197
# Player ID : 18734
# Num Minutes Played : 36
# Player ID : 20845
# Num Minutes Played : 161
# Player ID : 21298
# Num Minutes Played : 102
# Player ID : 31917
# Num Minutes Played : 152
# Player ID : 38178
# Num Minutes Played : 12
# Player ID : 39273
# Num Minutes Played : 41
# Player ID : 3086
# Num Minutes Played : 292
# Player ID : 3517
# Num Minutes Played : 276
# Player ID : 3853
# Num Minutes Played : 273
# Player ID : 4567
# Num Minutes Played : 40
# Player ID : 4774
# Num Minutes Played : 233
# Player ID : 4934
# Num Minutes Played : 27
# Player ID : 6399
# Num Minutes Played : 292
# Player ID : 9540
# Num Minutes Played : 44
# Player ID : 9914
# Num Minutes Played : 292
# Player ID : 10928
# Num Minutes Played : 0
# Player ID : 10931
# Num Minutes Played : 268
# Player ID : 11250
# Num Minutes Played : 292
# Player ID : 11252
# Num Minutes Played : 249
# Player ID : 22074
# Num Minutes Played : 254
# Player ID : 33144
# Num Minutes Played : 0
# Player ID : 34794
# Num Minutes Played : 62
# Player ID : 3166
# Num Minutes Played : 319
# Player ID : 4355
# Num Minutes Played : 218
# Player ID : 6993
# Num Minutes Played : 142
# Player ID : 7002
# Num Minutes Played : 81
# Player ID : 7024
# Num Minutes Played : 671
# Player ID : 7036
# Num Minutes Played : 671
# Player ID : 7119
# Num Minutes Played : 200
# Player ID : 7156
# Num Minutes Played : 371
# Player ID : 7173
# Num Minutes Played : 671
# Player ID : 7469
# Num Minutes Played : 0
# Player ID : 7471
# Num Minutes Played : 159
# Player ID : 7480
# Num Minutes Played : 0
# Player ID : 7777
# Num Minutes Played : 68
# Player ID : 11601
# Num Minutes Played : 119
# Player ID : 25048
# Num Minutes Played : 0
# Player ID : 30707
# Num Minutes Played : 0
# Player ID : 6954
# Num Minutes Played : 349
# Player ID : 7037
# Num Minutes Played : 438
# Player ID : 7038
# Num Minutes Played : 250
# Player ID : 7131
# Num Minutes Played : 334
# Player ID : 7788
# Num Minutes Played : 393
# Player ID : 8181
# Num Minutes Played : 404
# Player ID : 11514
# Num Minutes Played : 504
# Player ID : 31953
# Num Minutes Played : 145
# Player ID : 3702
# Num Minutes Played : 324
# Player ID : 5611
# Num Minutes Played : 0
# Player ID : 5612
# Num Minutes Played : 226
# Player ID : 5613
# Num Minutes Played : 80
# Player ID : 5617
# Num Minutes Played : 291
# Player ID : 5621
# Num Minutes Played : 276
# Player ID : 5622
# Num Minutes Played : 324
# Player ID : 5624
# Num Minutes Played : 324
# Player ID : 5625
# Num Minutes Played : 292
# Player ID : 6358
# Num Minutes Played : 98
# Player ID : 8552
# Num Minutes Played : 118
# Player ID : 8819
# Num Minutes Played : 235
# Player ID : 11098
# Num Minutes Played : 130
# Player ID : 20871
# Num Minutes Played : 61
# Player ID : 23444
# Num Minutes Played : 282
# Player ID : 26875
# Num Minutes Played : 292
# Player ID : 3711
# Num Minutes Played : 193
# Player ID : 4421
# Num Minutes Played : 193
# Player ID : 6990
# Num Minutes Played : 193
# Player ID : 7025
# Num Minutes Played : 188
# Player ID : 7975
# Num Minutes Played : 159
# Player ID : 8967
# Num Minutes Played : 136
# Player ID : 9722
# Num Minutes Played : 178
# Player ID : 10919
# Num Minutes Played : 193
# Player ID : 10922
# Num Minutes Played : 26
# Player ID : 10927
# Num Minutes Played : 61
# Player ID : 11383
# Num Minutes Played : 5
# Player ID : 16041
# Num Minutes Played : 15
# Player ID : 16307
# Num Minutes Played : 159
# Player ID : 16879
# Num Minutes Played : 0
# Player ID : 28044
# Num Minutes Played : 15
# Player ID : 30397
# Num Minutes Played : 193
# Player ID : 3168
# Num Minutes Played : 141
# Player ID : 3193
# Num Minutes Played : 204
# Player ID : 3593
# Num Minutes Played : 186
# Player ID : 5204
# Num Minutes Played : 153
# Player ID : 5205
# Num Minutes Played : 293
# Player ID : 5206
# Num Minutes Played : 293
# Player ID : 5207
# Num Minutes Played : 293
# Player ID : 5209
# Num Minutes Played : 293
# Player ID : 5214
# Num Minutes Played : 81
# Player ID : 5218
# Num Minutes Played : 41
# Player ID : 6374
# Num Minutes Played : 179
# Player ID : 9929
# Num Minutes Played : 252
# Player ID : 10327
# Num Minutes Played : 25
# Player ID : 13621
# Num Minutes Played : 159
# Player ID : 20016
# Num Minutes Played : 293
# Player ID : 3053
# Num Minutes Played : 128
# Player ID : 3167
# Num Minutes Played : 290
# Player ID : 3493
# Num Minutes Played : 20
# Player ID : 5562
# Num Minutes Played : 219
# Player ID : 5570
# Num Minutes Played : 290
# Player ID : 5572
# Num Minutes Played : 290
# Player ID : 5574
# Num Minutes Played : 290
# Player ID : 5579
# Num Minutes Played : 290
# Player ID : 6322
# Num Minutes Played : 0
# Player ID : 6324
# Num Minutes Played : 132
# Player ID : 6985
# Num Minutes Played : 259
# Player ID : 8400
# Num Minutes Played : 169
# Player ID : 8525
# Num Minutes Played : 0
# Player ID : 8808
# Num Minutes Played : 258
# Player ID : 8966
# Num Minutes Played : 237
# Player ID : 10287
# Num Minutes Played : 158
# Player ID : 9927
# Num Minutes Played : 0
# Player ID : 11173
# Num Minutes Played : 18
# Player ID : 12169
# Num Minutes Played : 79
# Player ID : 16028
# Num Minutes Played : 97
# Player ID : 2999
# Num Minutes Played : 326
# Player ID : 3009
# Num Minutes Played : 326
# Player ID : 3026
# Num Minutes Played : 283
# Player ID : 3091
# Num Minutes Played : 38
# Player ID : 3099
# Num Minutes Played : 326
# Player ID : 3961
# Num Minutes Played : 326
# Player ID : 4445
# Num Minutes Played : 0
# Player ID : 5480
# Num Minutes Played : 31
# Player ID : 5484
# Num Minutes Played : 99
# Player ID : 5485
# Num Minutes Played : 326
# Player ID : 5487
# Num Minutes Played : 288
# Player ID : 6849
# Num Minutes Played : 99
# Player ID : 8217
# Num Minutes Played : 118
# Player ID : 19677
# Num Minutes Played : 268
# Player ID : 20004
# Num Minutes Played : 306
# Player ID : 4767
# Num Minutes Played : 195
# Player ID : 6971
# Num Minutes Played : 128
# Player ID : 7039
# Num Minutes Played : 179
# Player ID : 8541
# Num Minutes Played : 89
# Player ID : 8963
# Num Minutes Played : 187
# Player ID : 10349
# Num Minutes Played : 187
# Player ID : 10826
# Num Minutes Played : 94
# Player ID : 11086
# Num Minutes Played : 187
# Player ID : 11088
# Num Minutes Played : 126
# Player ID : 12293
# Num Minutes Played : 93
# Player ID : 12555
# Num Minutes Played : 95
# Player ID : 21567
# Num Minutes Played : 18
# Player ID : 23558
# Num Minutes Played : 187
# Player ID : 29989
# Num Minutes Played : 76
# Player ID : 30311
# Num Minutes Played : 109
# Player ID : 30357
# Num Minutes Played : 187
# Player ID : 31042
# Num Minutes Played : 93
# Player ID : 3500
# Num Minutes Played : 319
# Player ID : 8286
# Num Minutes Played : 302
# Player ID : 3034
# Num Minutes Played : 193
# Player ID : 4626
# Num Minutes Played : 193
# Player ID : 4673
# Num Minutes Played : 158
# Player ID : 5660
# Num Minutes Played : 184
# Player ID : 5668
# Num Minutes Played : 193
# Player ID : 5669
# Num Minutes Played : 193
# Player ID : 5673
# Num Minutes Played : 193
# Player ID : 7964
# Num Minutes Played : 74
# Player ID : 7979
# Num Minutes Played : 74
# Player ID : 8737
# Num Minutes Played : 66
# Player ID : 8836
# Num Minutes Played : 107
# Player ID : 9622
# Num Minutes Played : 160
# Player ID : 26718
# Num Minutes Played : 23
# Player ID : 29480
# Num Minutes Played : 10
# Player ID : 30739
# Num Minutes Played : 0
# Player ID : 6655
# Num Minutes Played : 61
# Player ID : 4870
# Num Minutes Played : 385
# Player ID : 4875
# Num Minutes Played : 287
# Player ID : 7044
# Num Minutes Played : 335
# Player ID : 7801
# Num Minutes Played : 192
# Player ID : 8095
# Num Minutes Played : 189
# Player ID : 8579
# Num Minutes Played : 168
# Player ID : 11541
# Num Minutes Played : 385
# Player ID : 13197
# Num Minutes Played : 385
# Player ID : 16037
# Num Minutes Played : 67
# Player ID : 16469
# Num Minutes Played : 242
# Player ID : 16472
# Num Minutes Played : 261
# Player ID : 16570
# Num Minutes Played : 385
# Player ID : 23452
# Num Minutes Played : 109
# Player ID : 23454
# Num Minutes Played : 223
# Player ID : 28239
# Num Minutes Played : 64
# Player ID : 30328
# Num Minutes Played : 353
# Player ID : 3441
# Num Minutes Played : 181
# Player ID : 3471
# Num Minutes Played : 96
# Player ID : 5456
# Num Minutes Played : 259
# Player ID : 5460
# Num Minutes Played : 178
# Player ID : 5461
# Num Minutes Played : 94
# Player ID : 5463
# Num Minutes Played : 311
# Player ID : 5465
# Num Minutes Played : 158
# Player ID : 5468
# Num Minutes Played : 319
# Player ID : 5469
# Num Minutes Played : 294
# Player ID : 5474
# Num Minutes Played : 176
# Player ID : 7693
# Num Minutes Played : 133
# Player ID : 8946
# Num Minutes Played : 80
# Player ID : 16531
# Num Minutes Played : 319
# Player ID : 28368
# Num Minutes Played : 27
# Player ID : 33018
# Num Minutes Played : 295
# Player ID : 3325
# Num Minutes Played : 194
# Player ID : 3969
# Num Minutes Played : 308
# Player ID : 8220
# Num Minutes Played : 319
# Player ID : 8307
# Num Minutes Played : 319
# Player ID : 8309
# Num Minutes Played : 79
# Player ID : 8506
# Num Minutes Played : 256
# Player ID : 8513
# Num Minutes Played : 30
# Player ID : 8518
# Num Minutes Played : 319
# Player ID : 8769
# Num Minutes Played : 291
# Player ID : 8777
# Num Minutes Played : 95
# Player ID : 8779
# Num Minutes Played : 311
# Player ID : 8931
# Num Minutes Played : 11
# Player ID : 18762
# Num Minutes Played : 63
# Player ID : 20037
# Num Minutes Played : 0
# Player ID : 21532
# Num Minutes Played : 319
# Player ID : 24977
# Num Minutes Played : 192
# Player ID : 4713
# Num Minutes Played : 190
# Player ID : 6782
# Num Minutes Played : 155
# Player ID : 7146
# Num Minutes Played : 163
# Player ID : 10592
# Num Minutes Played : 190
# Player ID : 16535
# Num Minutes Played : 190
# Player ID : 16629
# Num Minutes Played : 66
# Player ID : 16740
# Num Minutes Played : 61
# Player ID : 18879
# Num Minutes Played : 164
# Player ID : 21397
# Num Minutes Played : 190
# Player ID : 30512
# Num Minutes Played : 118
# Player ID : 30644
# Num Minutes Played : 180
# Player ID : 44229
# Num Minutes Played : 27
# Player ID : 44962
# Num Minutes Played : 0
# Player ID : 46906
# Num Minutes Played : 190
# Player ID : 46915
# Num Minutes Played : 0
# Player ID : 6964
# Num Minutes Played : 6
# Player ID : 8247
# Num Minutes Played : 72
# Player ID : 4809
# Num Minutes Played : 33
# Player ID : 27622
# Num Minutes Played : 0
# Player ID : 3205
# Num Minutes Played : 542
# Player ID : 3233
# Num Minutes Played : 608
# Player ID : 3244
# Num Minutes Played : 623
# Player ID : 3308
# Num Minutes Played : 281
# Player ID : 3318
# Num Minutes Played : 74
# Player ID : 3336
# Num Minutes Played : 452
# Player ID : 3382
# Num Minutes Played : 544
# Player ID : 3468
# Num Minutes Played : 638
# Player ID : 3470
# Num Minutes Played : 3
# Player ID : 3532
# Num Minutes Played : 215
# Player ID : 3943
# Num Minutes Played : 496
# Player ID : 4706
# Num Minutes Played : 638
# Player ID : 7843
# Num Minutes Played : 394
# Player ID : 10955
# Num Minutes Played : 606
# Player ID : 12423
# Num Minutes Played : 14
# Player ID : 30714
# Num Minutes Played : 39
# Player ID : 3575
# Num Minutes Played : 416
# Player ID : 8830
# Num Minutes Played : 367
# Player ID : 16311
# Num Minutes Played : 36
# Player ID : 16509
# Num Minutes Played : 105
# Player ID : 16514
# Num Minutes Played : 330
# Player ID : 18617
# Num Minutes Played : 416
# Player ID : 18618
# Num Minutes Played : 129
# Player ID : 20827
# Num Minutes Played : 278
# Player ID : 21294
# Num Minutes Played : 239
# Player ID : 22243
# Num Minutes Played : 416
# Player ID : 23649
# Num Minutes Played : 351
# Player ID : 31900
# Num Minutes Played : 416
# Player ID : 39136
# Num Minutes Played : 416
# Player ID : 2988
# Num Minutes Played : 271
# Player ID : 3311
# Num Minutes Played : 210
# Player ID : 3321
# Num Minutes Played : 210
# Player ID : 3567
# Num Minutes Played : 289
# Player ID : 7745
# Num Minutes Played : 16
# Player ID : 7787
# Num Minutes Played : 289
# Player ID : 7829
# Num Minutes Played : 176
# Player ID : 8069
# Num Minutes Played : 148
# Player ID : 8118
# Num Minutes Played : 289
# Player ID : 8125
# Num Minutes Played : 289
# Player ID : 13360
# Num Minutes Played : 40
# Player ID : 15582
# Num Minutes Played : 94
# Player ID : 20201
# Num Minutes Played : 289
# Player ID : 20750
# Num Minutes Played : 0
# Player ID : 21809
# Num Minutes Played : 104
# Player ID : 23230
# Num Minutes Played : 21
# Player ID : 30262
# Num Minutes Played : 0
# Player ID : 30322
# Num Minutes Played : 50
# Player ID : 41836
# Num Minutes Played : 0
# Player ID : 9638
# Num Minutes Played : 234
# Player ID : 22084
# Num Minutes Played : 220
# Player ID : 5557
# Num Minutes Played : 53
# Player ID : 39565
# Num Minutes Played : 12
# Player ID : 7966
# Num Minutes Played : 0
# Player ID : 22818
# Num Minutes Played : 41
# Player ID : 11000
# Num Minutes Played : 95
# Player ID : 16557
# Num Minutes Played : 233
# Player ID : 18881
# Num Minutes Played : 34
# Player ID : 23725
# Num Minutes Played : 0
# Player ID : 25079
# Num Minutes Played : 0
# Player ID : 6596
# Num Minutes Played : 0
# Player ID : 6307
# Num Minutes Played : 94
# Player ID : 8654
# Num Minutes Played : 0
# Player ID : 11603
# Num Minutes Played : 10
# Player ID : 16527
# Num Minutes Played : 0
# Player ID : 29163
# Num Minutes Played : 96
# Player ID : 12041
# Num Minutes Played : 0
# Player ID : 2954
# Num Minutes Played : 261
# Player ID : 3077
# Num Minutes Played : 274
# Player ID : 3089
# Num Minutes Played : 241
# Player ID : 3176
# Num Minutes Played : 254
# Player ID : 3289
# Num Minutes Played : 374
# Player ID : 3509
# Num Minutes Played : 384
# Player ID : 3621
# Num Minutes Played : 152
# Player ID : 5630
# Num Minutes Played : 148
# Player ID : 5632
# Num Minutes Played : 288
# Player ID : 5633
# Num Minutes Played : 139
# Player ID : 5642
# Num Minutes Played : 230
# Player ID : 6331
# Num Minutes Played : 154
# Player ID : 6332
# Num Minutes Played : 211
# Player ID : 20005
# Num Minutes Played : 290
# Player ID : 9086
# Num Minutes Played : 0
# Player ID : 9164
# Num Minutes Played : 0
# Player ID : 11281
# Num Minutes Played : 64
# Player ID : 11396
# Num Minutes Played : 129
# Player ID : 8215
# Num Minutes Played : 12
# Player ID : 7162
# Num Minutes Played : 187
# Player ID : 8407
# Num Minutes Played : 121
# Player ID : 8509
# Num Minutes Played : 195
# Player ID : 8524
# Num Minutes Played : 195
# Player ID : 10794
# Num Minutes Played : 107
# Player ID : 11268
# Num Minutes Played : 187
# Player ID : 12723
# Num Minutes Played : 74
# Player ID : 16502
# Num Minutes Played : 166
# Player ID : 16741
# Num Minutes Played : 130
# Player ID : 19316
# Num Minutes Played : 176
# Player ID : 22565
# Num Minutes Played : 19
# Player ID : 31887
# Num Minutes Played : 195
# Player ID : 42822
# Num Minutes Played : 144
# Player ID : 46376
# Num Minutes Played : 195
# Player ID : 47435
# Num Minutes Played : 8
# Player ID : 11127
# Num Minutes Played : 0
# Player ID : 3581
# Num Minutes Played : 28
# Player ID : 3620
# Num Minutes Played : 187
# Player ID : 3655
# Num Minutes Played : 187
# Player ID : 9048
# Num Minutes Played : 171
# Player ID : 9466
# Num Minutes Played : 135
# Player ID : 9481
# Num Minutes Played : 187
# Player ID : 9645
# Num Minutes Played : 187
# Player ID : 9974
# Num Minutes Played : 187
# Player ID : 10002
# Num Minutes Played : 0
# Player ID : 10285
# Num Minutes Played : 84
# Player ID : 10534
# Num Minutes Played : 120
# Player ID : 10540
# Num Minutes Played : 92
# Player ID : 29571
# Num Minutes Played : 171
# Player ID : 37338
# Num Minutes Played : 0
# Player ID : 43563
# Num Minutes Played : 23
# Player ID : 3323
# Num Minutes Played : 186
# Player ID : 20355
# Num Minutes Played : 0
# Player ID : 3380
# Num Minutes Played : 0
# Player ID : 3457
# Num Minutes Played : 0
# Player ID : 4831
# Num Minutes Played : 75
# Player ID : 5639
# Num Minutes Played : 95
# Player ID : 13116
# Num Minutes Played : 96
# Player ID : 16281
# Num Minutes Played : 0
# Player ID : 16559
# Num Minutes Played : 0
# Player ID : 23650
# Num Minutes Played : 99
# Player ID : 8056
# Num Minutes Played : 13
# Player ID : 8667
# Num Minutes Played : 198
# Player ID : 9476
# Num Minutes Played : 157
# Player ID : 9725
# Num Minutes Played : 187
# Player ID : 12148
# Num Minutes Played : 11
# Player ID : 12807
# Num Minutes Played : 91
# Player ID : 13215
# Num Minutes Played : 198
# Player ID : 15416
# Num Minutes Played : 171
# Player ID : 16550
# Num Minutes Played : 198
# Player ID : 24303
# Num Minutes Played : 49
# Player ID : 24321
# Num Minutes Played : 198
# Player ID : 24455
# Num Minutes Played : 198
# Player ID : 24648
# Num Minutes Played : 77
# Player ID : 26939
# Num Minutes Played : 185
# Player ID : 38196
# Num Minutes Played : 198
# Player ID : 41828
# Num Minutes Played : 0
# Player ID : 16811
# Num Minutes Played : 64
# Player ID : 18735
# Num Minutes Played : 45
# Player ID : 10832
# Num Minutes Played : 0
# Player ID : 28332
# Num Minutes Played : 0
# Player ID : 8219
# Num Minutes Played : 39
# Player ID : 16018
# Num Minutes Played : 0
# Player ID : 21271
# Num Minutes Played : 0
# Player ID : 22212
# Num Minutes Played : 0
# Player ID : 3245
# Num Minutes Played : 0
# Player ID : 3604
# Num Minutes Played : 28
# Player ID : 5476
# Num Minutes Played : 227
# Player ID : 5477
# Num Minutes Played : 5
# Player ID : 46378
# Num Minutes Played : 0
# Player ID : 4354
# Num Minutes Played : 100
# Player ID : 9550
# Num Minutes Played : 0
# Player ID : 31067
# Num Minutes Played : 0
# Player ID : 4872
# Num Minutes Played : 0
# Player ID : 46909
# Num Minutes Played : 0
# Player ID : 46910
# Num Minutes Played : 0
# Player ID : 73852
# Num Minutes Played : 0
# Player ID : 17042
# Num Minutes Played : 32
# Player ID : 7015
# Num Minutes Played : 15
# Player ID : 21261
# Num Minutes Played : 64
# Player ID : 16301
# Num Minutes Played : 0
# Player ID : 4129
# Num Minutes Played : 0
# Player ID : 3306
# Num Minutes Played : 31
# Player ID : 6994
# Num Minutes Played : 148
# Player ID : 7890
# Num Minutes Played : 31
# Player ID : 8067
# Num Minutes Played : 0
# Player ID : 20033
# Num Minutes Played : 13
# Player ID : 31892
# Num Minutes Played : 0
# Player ID : 2972
# Num Minutes Played : 0
# Player ID : 6826
# Num Minutes Played : 0
# Player ID : 9397
# Num Minutes Played : 0
# Player ID : 22026
# Num Minutes Played : 0
# Player ID : 11278
# Num Minutes Played : 0
# Player ID : 11280
# Num Minutes Played : 0
# Player ID : 3637
# Num Minutes Played : 80
# Player ID : 5672
# Num Minutes Played : 0
# Player ID : 16290
# Num Minutes Played : 0
# Player ID : 20002
# Num Minutes Played : 45
# Player ID : 35653
# Num Minutes Played : 26
# Player ID : 26063
# Num Minutes Played : 0
# Player ID : 9621
# Num Minutes Played : 0
# Player ID : 10536
# Num Minutes Played : 0
# Player ID : 11116
# Num Minutes Played : 0
# Player ID : 12510
# Num Minutes Played : 0
# Player ID : 31890
# Num Minutes Played : 0
# Player ID : 32395
# Num Minutes Played : 0
# Player ID : 3043
# Num Minutes Played : 0
# Player ID : 21442
# Num Minutes Played : 0
# Player ID : 11333
# Num Minutes Played : 0
# Player ID : 6798
# Num Minutes Played : 0
# Player ID : 18927
# Num Minutes Played : 0
# Player ID : 27691
# Num Minutes Played : 0
# Player ID : 6989
# Num Minutes Played : 0
# Player ID : 5186
# Num Minutes Played : 0
# Player ID : 5193
# Num Minutes Played : 0
# Player ID : 34588
# Num Minutes Played : 0
# Player ID : 38119
# Num Minutes Played : 0
# =================================================================
# Competition Name :  FIFA World Cup 2022
# Player ID : 3500
# Num Minutes Played : 291
# Player ID : 3533
# Num Minutes Played : 170
# Player ID : 3913
# Num Minutes Played : 135
# Player ID : 5537
# Num Minutes Played : 45
# Player ID : 5538
# Num Minutes Played : 41
# Player ID : 5544
# Num Minutes Played : 284
# Player ID : 5545
# Num Minutes Played : 239
# Player ID : 5549
# Num Minutes Played : 291
# Player ID : 6983
# Num Minutes Played : 250
# Player ID : 7796
# Num Minutes Played : 184
# Player ID : 16022
# Num Minutes Played : 0
# Player ID : 16026
# Num Minutes Played : 203
# Player ID : 17974
# Num Minutes Played : 0
# Player ID : 29006
# Num Minutes Played : 54
# Player ID : 30401
# Num Minutes Played : 208
# Player ID : 3831
# Num Minutes Played : 201
# Player ID : 4269
# Num Minutes Played : 186
# Player ID : 5589
# Num Minutes Played : 183
# Player ID : 5591
# Num Minutes Played : 97
# Player ID : 5603
# Num Minutes Played : 201
# Player ID : 5833
# Num Minutes Played : 60
# Player ID : 6318
# Num Minutes Played : 141
# Player ID : 6319
# Num Minutes Played : 0
# Player ID : 6321
# Num Minutes Played : 182
# Player ID : 6687
# Num Minutes Played : 169
# Player ID : 6901
# Num Minutes Played : 118
# Player ID : 7117
# Num Minutes Played : 6
# Player ID : 16489
# Num Minutes Played : 57
# Player ID : 18015
# Num Minutes Played : 32
# Player ID : 20600
# Num Minutes Played : 201
# Player ID : 27719
# Num Minutes Played : 160
# Player ID : 3090
# Num Minutes Played : 687
# Player ID : 5503
# Num Minutes Played : 687
# Player ID : 5507
# Num Minutes Played : 405
# Player ID : 6909
# Num Minutes Played : 687
# Player ID : 7006
# Num Minutes Played : 64
# Player ID : 7797
# Num Minutes Played : 573
# Player ID : 11456
# Num Minutes Played : 271
# Player ID : 19597
# Num Minutes Played : 348
# Player ID : 20572
# Num Minutes Played : 513
# Player ID : 27768
# Num Minutes Played : 309
# Player ID : 27886
# Num Minutes Played : 517
# Player ID : 28263
# Num Minutes Played : 126
# Player ID : 28268
# Num Minutes Played : 50
# Player ID : 29201
# Num Minutes Played : 551
# Player ID : 29560
# Num Minutes Played : 439
# Player ID : 38718
# Num Minutes Played : 544
# Player ID : 3240
# Num Minutes Played : 302
# Player ID : 3281
# Num Minutes Played : 302
# Player ID : 5479
# Num Minutes Played : 302
# Player ID : 5481
# Num Minutes Played : 282
# Player ID : 5490
# Num Minutes Played : 289
# Player ID : 8346
# Num Minutes Played : 212
# Player ID : 8859
# Num Minutes Played : 41
# Player ID : 9980
# Num Minutes Played : 48
# Player ID : 15957
# Num Minutes Played : 133
# Player ID : 22293
# Num Minutes Played : 302
# Player ID : 28370
# Num Minutes Played : 79
# Player ID : 33477
# Num Minutes Played : 221
# Player ID : 33488
# Num Minutes Played : 78
# Player ID : 33492
# Num Minutes Played : 212
# Player ID : 33495
# Num Minutes Played : 302
# Player ID : 227697
# Num Minutes Played : 25
# Player ID : 3043
# Num Minutes Played : 201
# Player ID : 3570
# Num Minutes Played : 201
# Player ID : 3815
# Num Minutes Played : 201
# Player ID : 3959
# Num Minutes Played : 201
# Player ID : 4447
# Num Minutes Played : 55
# Player ID : 5732
# Num Minutes Played : 78
# Player ID : 6302
# Num Minutes Played : 93
# Player ID : 8247
# Num Minutes Played : 201
# Player ID : 16190
# Num Minutes Played : 195
# Player ID : 16294
# Num Minutes Played : 0
# Player ID : 16554
# Num Minutes Played : 201
# Player ID : 17042
# Num Minutes Played : 68
# Player ID : 18722
# Num Minutes Played : 34
# Player ID : 24443
# Num Minutes Played : 131
# Player ID : 24547
# Num Minutes Played : 6
# Player ID : 27569
# Num Minutes Played : 120
# Player ID : 22371
# Num Minutes Played : 0
# Player ID : 3063
# Num Minutes Played : 204
# Player ID : 3202
# Num Minutes Played : 89
# Player ID : 3280
# Num Minutes Played : 254
# Player ID : 3295
# Num Minutes Played : 322
# Player ID : 4320
# Num Minutes Played : 213
# Player ID : 4372
# Num Minutes Played : 368
# Player ID : 5539
# Num Minutes Played : 322
# Player ID : 5547
# Num Minutes Played : 308
# Player ID : 6945
# Num Minutes Played : 106
# Player ID : 9904
# Num Minutes Played : 135
# Player ID : 10595
# Num Minutes Played : 248
# Player ID : 18395
# Num Minutes Played : 235
# Player ID : 22600
# Num Minutes Played : 251
# Player ID : 25104
# Num Minutes Played : 186
# Player ID : 25363
# Num Minutes Played : 177
# Player ID : 29976
# Num Minutes Played : 125
# Player ID : 7145
# Num Minutes Played : 0
# Player ID : 7993
# Num Minutes Played : 0
# Player ID : 30179
# Num Minutes Played : 0
# Player ID : 3196
# Num Minutes Played : 61
# Player ID : 3557
# Num Minutes Played : 31
# Player ID : 3767
# Num Minutes Played : 205
# Player ID : 5650
# Num Minutes Played : 10
# Player ID : 5651
# Num Minutes Played : 205
# Player ID : 5655
# Num Minutes Played : 101
# Player ID : 9236
# Num Minutes Played : 91
# Player ID : 16352
# Num Minutes Played : 127
# Player ID : 23910
# Num Minutes Played : 83
# Player ID : 30681
# Num Minutes Played : 121
# Player ID : 32450
# Num Minutes Played : 205
# Player ID : 44955
# Num Minutes Played : 195
# Player ID : 105943
# Num Minutes Played : 205
# Player ID : 105944
# Num Minutes Played : 114
# Player ID : 128793
# Num Minutes Played : 17
# Player ID : 24475
# Num Minutes Played : 25
# Player ID : 2941
# Num Minutes Played : 279
# Player ID : 3404
# Num Minutes Played : 302
# Player ID : 3436
# Num Minutes Played : 205
# Player ID : 4506
# Num Minutes Played : 282
# Player ID : 5675
# Num Minutes Played : 302
# Player ID : 7379
# Num Minutes Played : 302
# Player ID : 8553
# Num Minutes Played : 263
# Player ID : 15970
# Num Minutes Played : 122
# Player ID : 20611
# Num Minutes Played : 247
# Player ID : 21026
# Num Minutes Played : 79
# Player ID : 31751
# Num Minutes Played : 78
# Player ID : 32915
# Num Minutes Played : 208
# Player ID : 80484
# Num Minutes Played : 68
# Player ID : 88123
# Num Minutes Played : 107
# Player ID : 12583
# Num Minutes Played : 0
# Player ID : 24085
# Num Minutes Played : 199
# Player ID : 28559
# Num Minutes Played : 172
# Player ID : 30111
# Num Minutes Played : 199
# Player ID : 31152
# Num Minutes Played : 192
# Player ID : 34396
# Num Minutes Played : 170
# Player ID : 36148
# Num Minutes Played : 20
# Player ID : 37522
# Num Minutes Played : 199
# Player ID : 37726
# Num Minutes Played : 193
# Player ID : 37737
# Num Minutes Played : 199
# Player ID : 37945
# Num Minutes Played : 6
# Player ID : 38004
# Num Minutes Played : 199
# Player ID : 40211
# Num Minutes Played : 51
# Player ID : 51969
# Num Minutes Played : 99
# Player ID : 91090
# Num Minutes Played : 0
# Player ID : 2988
# Num Minutes Played : 244
# Player ID : 3306
# Num Minutes Played : 393
# Player ID : 3311
# Num Minutes Played : 397
# Player ID : 3669
# Num Minutes Played : 397
# Player ID : 6994
# Num Minutes Played : 154
# Player ID : 7745
# Num Minutes Played : 139
# Player ID : 7829
# Num Minutes Played : 36
# Player ID : 7891
# Num Minutes Played : 170
# Player ID : 8118
# Num Minutes Played : 386
# Player ID : 8125
# Num Minutes Played : 397
# Player ID : 8259
# Num Minutes Played : 177
# Player ID : 8326
# Num Minutes Played : 397
# Player ID : 20033
# Num Minutes Played : 0
# Player ID : 20750
# Num Minutes Played : 354
# Player ID : 21547
# Num Minutes Played : 0
# Player ID : 21809
# Num Minutes Played : 295
# Player ID : 2995
# Num Minutes Played : 313
# Player ID : 7161
# Num Minutes Played : 27
# Player ID : 16308
# Num Minutes Played : 191
# Player ID : 3083
# Num Minutes Played : 300
# Player ID : 5604
# Num Minutes Played : 284
# Player ID : 5618
# Num Minutes Played : 226
# Player ID : 5623
# Num Minutes Played : 144
# Player ID : 22740
# Num Minutes Played : 147
# Player ID : 23763
# Num Minutes Played : 271
# Player ID : 29966
# Num Minutes Played : 51
# Player ID : 37641
# Num Minutes Played : 300
# Player ID : 40538
# Num Minutes Played : 248
# Player ID : 40542
# Num Minutes Played : 282
# Player ID : 40558
# Num Minutes Played : 68
# Player ID : 40672
# Num Minutes Played : 300
# Player ID : 41711
# Num Minutes Played : 60
# Player ID : 43565
# Num Minutes Played : 193
# Player ID : 4319
# Num Minutes Played : 109
# Player ID : 5246
# Num Minutes Played : 101
# Player ID : 5248
# Num Minutes Played : 0
# Player ID : 5249
# Num Minutes Played : 63
# Player ID : 5255
# Num Minutes Played : 138
# Player ID : 5259
# Num Minutes Played : 210
# Player ID : 5260
# Num Minutes Played : 135
# Player ID : 5264
# Num Minutes Played : 210
# Player ID : 6773
# Num Minutes Played : 210
# Player ID : 7104
# Num Minutes Played : 195
# Player ID : 28729
# Num Minutes Played : 35
# Player ID : 32478
# Num Minutes Played : 160
# Player ID : 34476
# Num Minutes Played : 15
# Player ID : 36288
# Num Minutes Played : 112
# Player ID : 36710
# Num Minutes Played : 210
# Player ID : 3193
# Num Minutes Played : 288
# Player ID : 5204
# Num Minutes Played : 292
# Player ID : 5206
# Num Minutes Played : 300
# Player ID : 5207
# Num Minutes Played : 260
# Player ID : 5209
# Num Minutes Played : 259
# Player ID : 7005
# Num Minutes Played : 301
# Player ID : 9927
# Num Minutes Played : 227
# Player ID : 10868
# Num Minutes Played : 120
# Player ID : 11184
# Num Minutes Played : 132
# Player ID : 12041
# Num Minutes Played : 247
# Player ID : 16028
# Num Minutes Played : 195
# Player ID : 18360
# Num Minutes Played : 96
# Player ID : 20016
# Num Minutes Played : 297
# Player ID : 32975
# Num Minutes Played : 398
# Player ID : 34639
# Num Minutes Played : 104
# Player ID : 38803
# Num Minutes Played : 106
# Player ID : 3625
# Num Minutes Played : 408
# Player ID : 5219
# Num Minutes Played : 444
# Player ID : 5234
# Num Minutes Played : 619
# Player ID : 5237
# Num Minutes Played : 601
# Player ID : 5245
# Num Minutes Played : 581
# Player ID : 6301
# Num Minutes Played : 501
# Player ID : 6785
# Num Minutes Played : 521
# Player ID : 7459
# Num Minutes Played : 246
# Player ID : 21736
# Num Minutes Played : 82
# Player ID : 23774
# Num Minutes Played : 388
# Player ID : 31295
# Num Minutes Played : 263
# Player ID : 46258
# Num Minutes Played : 508
# Player ID : 67700
# Num Minutes Played : 37
# Player ID : 102668
# Num Minutes Played : 9
# Player ID : 139016
# Num Minutes Played : 162
# Player ID : 296254
# Num Minutes Played : 48
# Player ID : 2972
# Num Minutes Played : 100
# Player ID : 3009
# Num Minutes Played : 546
# Player ID : 3026
# Num Minutes Played : 448
# Player ID : 3099
# Num Minutes Played : 506
# Player ID : 3604
# Num Minutes Played : 406
# Player ID : 4445
# Num Minutes Played : 404
# Player ID : 5477
# Num Minutes Played : 423
# Player ID : 5485
# Num Minutes Played : 443
# Player ID : 5487
# Num Minutes Played : 531
# Player ID : 6704
# Num Minutes Played : 494
# Player ID : 7439
# Num Minutes Played : 112
# Player ID : 8217
# Num Minutes Played : 154
# Player ID : 8519
# Num Minutes Played : 408
# Player ID : 10481
# Num Minutes Played : 555
# Player ID : 11135
# Num Minutes Played : 329
# Player ID : 11990
# Num Minutes Played : 232
# Player ID : 22097
# Num Minutes Played : 121
# Player ID : 24778
# Num Minutes Played : 104
# Player ID : 5743
# Num Minutes Played : 22
# Player ID : 5187
# Num Minutes Played : 216
# Player ID : 5188
# Num Minutes Played : 3
# Player ID : 5713
# Num Minutes Played : 216
# Player ID : 5714
# Num Minutes Played : 216
# Player ID : 5715
# Num Minutes Played : 216
# Player ID : 51094
# Num Minutes Played : 123
# Player ID : 51096
# Num Minutes Played : 0
# Player ID : 51099
# Num Minutes Played : 201
# Player ID : 51103
# Num Minutes Played : 0
# Player ID : 51469
# Num Minutes Played : 178
# Player ID : 51470
# Num Minutes Played : 0
# Player ID : 51546
# Num Minutes Played : 109
# Player ID : 51705
# Num Minutes Played : 13
# Player ID : 51710
# Num Minutes Played : 216
# Player ID : 57620
# Num Minutes Played : 59
# Player ID : 5567
# Num Minutes Played : 99
# Player ID : 5568
# Num Minutes Played : 58
# Player ID : 5571
# Num Minutes Played : 176
# Player ID : 5573
# Num Minutes Played : 200
# Player ID : 5576
# Num Minutes Played : 200
# Player ID : 5577
# Num Minutes Played : 200
# Player ID : 15452
# Num Minutes Played : 45
# Player ID : 26280
# Num Minutes Played : 0
# Player ID : 26297
# Num Minutes Played : 27
# Player ID : 26301
# Num Minutes Played : 155
# Player ID : 26318
# Num Minutes Played : 0
# Player ID : 26368
# Num Minutes Played : 200
# Player ID : 26400
# Num Minutes Played : 72
# Player ID : 26406
# Num Minutes Played : 99
# Player ID : 28825
# Num Minutes Played : 200
# Player ID : 30500
# Num Minutes Played : 70
# Player ID : 28637
# Num Minutes Played : 0
# Player ID : 3034
# Num Minutes Played : 307
# Player ID : 3637
# Num Minutes Played : 278
# Player ID : 4685
# Num Minutes Played : 0
# Player ID : 4734
# Num Minutes Played : 307
# Player ID : 5660
# Num Minutes Played : 262
# Player ID : 5668
# Num Minutes Played : 307
# Player ID : 5669
# Num Minutes Played : 307
# Player ID : 5673
# Num Minutes Played : 307
# Player ID : 7979
# Num Minutes Played : 221
# Player ID : 8714
# Num Minutes Played : 0
# Player ID : 8836
# Num Minutes Played : 0
# Player ID : 11737
# Num Minutes Played : 190
# Player ID : 12493
# Num Minutes Played : 27
# Player ID : 28453
# Num Minutes Played : 0
# Player ID : 31955
# Num Minutes Played : 206
# Player ID : 44166
# Num Minutes Played : 294
# Player ID : 7097
# Num Minutes Played : 0
# Player ID : 17043
# Num Minutes Played : 0
# Player ID : 26404
# Num Minutes Played : 0
# Player ID : 5563
# Num Minutes Played : 0
# Player ID : 5575
# Num Minutes Played : 72
# Player ID : 11388
# Num Minutes Played : 0
# Player ID : 15872
# Num Minutes Played : 0
# Player ID : 26375
# Num Minutes Played : 0
# Player ID : 11183
# Num Minutes Played : 57
# Player ID : 13620
# Num Minutes Played : 278
# Player ID : 25142
# Num Minutes Played : 46
# Player ID : 5543
# Num Minutes Played : 66
# Player ID : 5550
# Num Minutes Played : 195
# Player ID : 8561
# Num Minutes Played : 26
# Player ID : 8814
# Num Minutes Played : 98
# Player ID : 12326
# Num Minutes Played : 0
# Player ID : 16016
# Num Minutes Played : 0
# Player ID : 50436
# Num Minutes Played : 16
# Player ID : 3264
# Num Minutes Played : 63
# Player ID : 4318
# Num Minutes Played : 138
# Player ID : 21879
# Num Minutes Played : 0
# Player ID : 40784
# Num Minutes Played : 203
# Player ID : 124488
# Num Minutes Played : 157
# Player ID : 124490
# Num Minutes Played : 0
# Player ID : 124492
# Num Minutes Played : 175
# Player ID : 124493
# Num Minutes Played : 203
# Player ID : 124494
# Num Minutes Played : 203
# Player ID : 124495
# Num Minutes Played : 179
# Player ID : 124500
# Num Minutes Played : 103
# Player ID : 124506
# Num Minutes Played : 189
# Player ID : 124510
# Num Minutes Played : 103
# Player ID : 124512
# Num Minutes Played : 0
# Player ID : 124514
# Num Minutes Played : 128
# Player ID : 124899
# Num Minutes Played : 103
# Player ID : 124900
# Num Minutes Played : 189
# Player ID : 124901
# Num Minutes Played : 46
# Player ID : 149463
# Num Minutes Played : 0
# Player ID : 5214
# Num Minutes Played : 144
# Player ID : 29012
# Num Minutes Played : 7
# Player ID : 41655
# Num Minutes Played : 0
# Player ID : 3675
# Num Minutes Played : 0
# Player ID : 13314
# Num Minutes Played : 80
# Player ID : 20758
# Num Minutes Played : 145
# Player ID : 50498
# Num Minutes Played : 20
# Player ID : 3205
# Num Minutes Played : 165
# Player ID : 3244
# Num Minutes Played : 412
# Player ID : 3318
# Num Minutes Played : 146
# Player ID : 3336
# Num Minutes Played : 382
# Player ID : 3382
# Num Minutes Played : 385
# Player ID : 3468
# Num Minutes Played : 415
# Player ID : 3532
# Num Minutes Played : 207
# Player ID : 3943
# Num Minutes Played : 378
# Player ID : 4354
# Num Minutes Played : 220
# Player ID : 4706
# Num Minutes Played : 37
# Player ID : 7843
# Num Minutes Played : 201
# Player ID : 9638
# Num Minutes Played : 82
# Player ID : 10955
# Num Minutes Played : 350
# Player ID : 10956
# Num Minutes Played : 33
# Player ID : 22084
# Num Minutes Played : 244
# Player ID : 30714
# Num Minutes Played : 389
# Player ID : 3441
# Num Minutes Played : 204
# Player ID : 5456
# Num Minutes Played : 576
# Player ID : 5460
# Num Minutes Played : 431
# Player ID : 5463
# Num Minutes Played : 602
# Player ID : 5474
# Num Minutes Played : 617
# Player ID : 7693
# Num Minutes Played : 233
# Player ID : 11603
# Num Minutes Played : 270
# Player ID : 16527
# Num Minutes Played : 98
# Player ID : 16531
# Num Minutes Played : 652
# Player ID : 22041
# Num Minutes Played : 199
# Player ID : 28914
# Num Minutes Played : 91
# Player ID : 32602
# Num Minutes Played : 0
# Player ID : 33018
# Num Minutes Played : 652
# Player ID : 37148
# Num Minutes Played : 0
# Player ID : 49337
# Num Minutes Played : 0
# Player ID : 3634
# Num Minutes Played : 161
# Player ID : 21214
# Num Minutes Played : 0
# Player ID : 131037
# Num Minutes Played : 0
# Player ID : 156734
# Num Minutes Played : 0
# Player ID : 6377
# Num Minutes Played : 0
# Player ID : 21081
# Num Minutes Played : 0
# Player ID : 3471
# Num Minutes Played : 553
# Player ID : 5469
# Num Minutes Played : 544
# Player ID : 12625
# Num Minutes Played : 412
# Player ID : 29163
# Num Minutes Played : 553
# Player ID : 3233
# Num Minutes Played : 152
# Player ID : 15890
# Num Minutes Played : 340
# Player ID : 59493
# Num Minutes Played : 58
# Player ID : 149714
# Num Minutes Played : 96
# Player ID : 25305
# Num Minutes Played : 37
# Player ID : 8654
# Num Minutes Played : 111
# Player ID : 3477
# Num Minutes Played : 141
# Player ID : 4353
# Num Minutes Played : 200
# Player ID : 5203
# Num Minutes Played : 263
# Player ID : 5211
# Num Minutes Played : 180
# Player ID : 5719
# Num Minutes Played : 181
# Player ID : 6583
# Num Minutes Played : 42
# Player ID : 6720
# Num Minutes Played : 0
# Player ID : 6748
# Num Minutes Played : 157
# Player ID : 6765
# Num Minutes Played : 298
# Player ID : 6840
# Num Minutes Played : 0
# Player ID : 11748
# Num Minutes Played : 298
# Player ID : 16532
# Num Minutes Played : 298
# Player ID : 30486
# Num Minutes Played : 256
# Player ID : 30756
# Num Minutes Played : 30
# Player ID : 39161
# Num Minutes Played : 118
# Player ID : 68574
# Num Minutes Played : 117
# Player ID : 133353
# Num Minutes Played : 238
# Player ID : 12149
# Num Minutes Played : 294
# Player ID : 3300
# Num Minutes Played : 298
# Player ID : 3530
# Num Minutes Played : 79
# Player ID : 5690
# Num Minutes Played : 152
# Player ID : 8361
# Num Minutes Played : 147
# Player ID : 8776
# Num Minutes Played : 40
# Player ID : 8949
# Num Minutes Played : 129
# Player ID : 9411
# Num Minutes Played : 269
# Player ID : 23527
# Num Minutes Played : 232
# Player ID : 23721
# Num Minutes Played : 211
# Player ID : 23730
# Num Minutes Played : 88
# Player ID : 25719
# Num Minutes Played : 298
# Player ID : 30628
# Num Minutes Played : 124
# Player ID : 37208
# Num Minutes Played : 163
# Player ID : 37211
# Num Minutes Played : 130
# Player ID : 37215
# Num Minutes Played : 98
# Player ID : 37221
# Num Minutes Played : 194
# Player ID : 11127
# Num Minutes Played : 0
# Player ID : 4324
# Num Minutes Played : 103
# Player ID : 11493
# Num Minutes Played : 103
# Player ID : 25101
# Num Minutes Played : 0
# Player ID : 5620
# Num Minutes Played : 31
# Player ID : 5986
# Num Minutes Played : 0
# Player ID : 23264
# Num Minutes Played : 0
# Player ID : 4626
# Num Minutes Played : 0
# Player ID : 4664
# Num Minutes Played : 73
# Player ID : 5665
# Num Minutes Played : 90
# Player ID : 5667
# Num Minutes Played : 0
# Player ID : 50502
# Num Minutes Played : 45
# Player ID : 8069
# Num Minutes Played : 102
# Player ID : 39167
# Num Minutes Played : 0
# Player ID : 3377
# Num Minutes Played : 261
# Player ID : 3658
# Num Minutes Played : 26
# Player ID : 4614
# Num Minutes Played : 304
# Player ID : 8246
# Num Minutes Played : 243
# Player ID : 8526
# Num Minutes Played : 216
# Player ID : 12352
# Num Minutes Played : 304
# Player ID : 12524
# Num Minutes Played : 216
# Player ID : 12751
# Num Minutes Played : 304
# Player ID : 18242
# Num Minutes Played : 304
# Player ID : 21881
# Num Minutes Played : 243
# Player ID : 22008
# Num Minutes Played : 133
# Player ID : 22433
# Num Minutes Played : 0
# Player ID : 23789
# Num Minutes Played : 13
# Player ID : 24243
# Num Minutes Played : 114
# Player ID : 34339
# Num Minutes Played : 12
# Player ID : 38792
# Num Minutes Played : 278
# Player ID : 12169
# Num Minutes Played : 45
# Player ID : 40874
# Num Minutes Played : 66
# Player ID : 41092
# Num Minutes Played : 0
# Player ID : 5258
# Num Minutes Played : 87
# Player ID : 6297
# Num Minutes Played : 21
# Player ID : 6300
# Num Minutes Played : 108
# Player ID : 3053
# Num Minutes Played : 101
# Player ID : 3167
# Num Minutes Played : 205
# Player ID : 5562
# Num Minutes Played : 138
# Player ID : 5570
# Num Minutes Played : 205
# Player ID : 5579
# Num Minutes Played : 205
# Player ID : 6322
# Num Minutes Played : 198
# Player ID : 6324
# Num Minutes Played : 76
# Player ID : 8400
# Num Minutes Played : 196
# Player ID : 8507
# Num Minutes Played : 56
# Player ID : 8511
# Num Minutes Played : 0
# Player ID : 8546
# Num Minutes Played : 67
# Player ID : 8804
# Num Minutes Played : 32
# Player ID : 10287
# Num Minutes Played : 127
# Player ID : 12034
# Num Minutes Played : 170
# Player ID : 24118
# Num Minutes Played : 104
# Player ID : 39565
# Num Minutes Played : 185
# Player ID : 5199
# Num Minutes Played : 35
# Player ID : 5721
# Num Minutes Played : 53
# Player ID : 3141
# Num Minutes Played : 201
# Player ID : 3499
# Num Minutes Played : 178
# Player ID : 3551
# Num Minutes Played : 112
# Player ID : 3639
# Num Minutes Played : 23
# Player ID : 4935
# Num Minutes Played : 148
# Player ID : 7426
# Num Minutes Played : 98
# Player ID : 7472
# Num Minutes Played : 98
# Player ID : 8591
# Num Minutes Played : 98
# Player ID : 11174
# Num Minutes Played : 118
# Player ID : 12623
# Num Minutes Played : 70
# Player ID : 13454
# Num Minutes Played : 201
# Player ID : 15326
# Num Minutes Played : 103
# Player ID : 16346
# Num Minutes Played : 201
# Player ID : 28966
# Num Minutes Played : 29
# Player ID : 30016
# Num Minutes Played : 69
# Player ID : 46903
# Num Minutes Played : 0
# Player ID : 3512
# Num Minutes Played : 0
# Player ID : 10477
# Num Minutes Played : 0
# Player ID : 18737
# Num Minutes Played : 0
# Player ID : 29595
# Num Minutes Played : 202
# Player ID : 37122
# Num Minutes Played : 0
# Player ID : 37209
# Num Minutes Played : 0
# Player ID : 38285
# Num Minutes Played : 0
# Player ID : 95272
# Num Minutes Played : 0
# Player ID : 5581
# Num Minutes Played : 204
# Player ID : 5582
# Num Minutes Played : 177
# Player ID : 5597
# Num Minutes Played : 204
# Player ID : 5598
# Num Minutes Played : 204
# Player ID : 5600
# Num Minutes Played : 103
# Player ID : 5836
# Num Minutes Played : 179
# Player ID : 5839
# Num Minutes Played : 196
# Player ID : 6328
# Num Minutes Played : 159
# Player ID : 108340
# Num Minutes Played : 72
# Player ID : 130185
# Num Minutes Played : 177
# Player ID : 132296
# Num Minutes Played : 73
# Player ID : 132497
# Num Minutes Played : 0
# Player ID : 132728
# Num Minutes Played : 92
# Player ID : 132756
# Num Minutes Played : 56
# Player ID : 132772
# Num Minutes Played : 0
# Player ID : 2954
# Num Minutes Played : 67
# Player ID : 3077
# Num Minutes Played : 196
# Player ID : 3089
# Num Minutes Played : 196
# Player ID : 3176
# Num Minutes Played : 144
# Player ID : 3289
# Num Minutes Played : 52
# Player ID : 3457
# Num Minutes Played : 81
# Player ID : 3509
# Num Minutes Played : 196
# Player ID : 3621
# Num Minutes Played : 72
# Player ID : 5630
# Num Minutes Played : 45
# Player ID : 5632
# Num Minutes Played : 35
# Player ID : 5642
# Num Minutes Played : 196
# Player ID : 6989
# Num Minutes Played : 196
# Player ID : 16559
# Num Minutes Played : 96
# Player ID : 20005
# Num Minutes Played : 196
# Player ID : 32688
# Num Minutes Played : 0
# Player ID : 48347
# Num Minutes Played : 54
# Player ID : 5233
# Num Minutes Played : 0
# Player ID : 8227
# Num Minutes Played : 35
# Player ID : 8966
# Num Minutes Played : 35
# Player ID : 38837
# Num Minutes Played : 0
# Player ID : 31090
# Num Minutes Played : 45
# Player ID : 3086
# Num Minutes Played : 169
# Player ID : 3488
# Num Minutes Played : 87
# Player ID : 3517
# Num Minutes Played : 189
# Player ID : 3853
# Num Minutes Played : 205
# Player ID : 4767
# Num Minutes Played : 205
# Player ID : 4774
# Num Minutes Played : 124
# Player ID : 4934
# Num Minutes Played : 179
# Player ID : 6399
# Num Minutes Played : 151
# Player ID : 9540
# Num Minutes Played : 78
# Player ID : 11250
# Num Minutes Played : 205
# Player ID : 11252
# Num Minutes Played : 127
# Player ID : 22074
# Num Minutes Played : 36
# Player ID : 29377
# Num Minutes Played : 100
# Player ID : 34794
# Num Minutes Played : 141
# Player ID : 50528
# Num Minutes Played : 0
# Player ID : 13035
# Num Minutes Played : 35
# Player ID : 22168
# Num Minutes Played : 95
# Player ID : 12803
# Num Minutes Played : 7
# Player ID : 23830
# Num Minutes Played : 99
# Player ID : 348757
# Num Minutes Played : 7
# Player ID : 124496
# Num Minutes Played : 0
# Player ID : 124503
# Num Minutes Played : 0
# Player ID : 124909
# Num Minutes Played : 14
# Player ID : 124504
# Num Minutes Played : 0
# Player ID : 5178
# Num Minutes Played : 0
# Player ID : 5183
# Num Minutes Played : 0
# Player ID : 5191
# Num Minutes Played : 74
# Player ID : 54144
# Num Minutes Played : 104
# Player ID : 56755
# Num Minutes Played : 94
# Player ID : 121539
# Num Minutes Played : 0
# Player ID : 2989
# Num Minutes Played : 92
# Player ID : 3347
# Num Minutes Played : 122
# Player ID : 3450
# Num Minutes Played : 69
# Player ID : 3709
# Num Minutes Played : 209
# Player ID : 6383
# Num Minutes Played : 209
# Player ID : 6393
# Num Minutes Played : 180
# Player ID : 8108
# Num Minutes Played : 209
# Player ID : 12259
# Num Minutes Played : 0
# Player ID : 12325
# Num Minutes Played : 209
# Player ID : 17033
# Num Minutes Played : 181
# Player ID : 23615
# Num Minutes Played : 0
# Player ID : 28616
# Num Minutes Played : 37
# Player ID : 30519
# Num Minutes Played : 209
# Player ID : 31029
# Num Minutes Played : 172
# Player ID : 33602
# Num Minutes Played : 35
# Player ID : 35658
# Num Minutes Played : 63
# Player ID : 3135
# Num Minutes Played : 0
# Player ID : 22067
# Num Minutes Played : 0
# Player ID : 40564
# Num Minutes Played : 98
# Player ID : 9286
# Num Minutes Played : 29
# Player ID : 44225
# Num Minutes Played : 63
# Player ID : 45047
# Num Minutes Played : 108
# Player ID : 4272
# Num Minutes Played : 83
# Player ID : 13621
# Num Minutes Played : 0
# Player ID : 51632
# Num Minutes Played : 0
# Player ID : 74623
# Num Minutes Played : 0
# Player ID : 5633
# Num Minutes Played : 45
# Player ID : 6331
# Num Minutes Played : 99
# Player ID : 23650
# Num Minutes Played : 0
# Player ID : 136306
# Num Minutes Played : 0
# Player ID : 36666
# Num Minutes Played : 0
# Player ID : 8808
# Num Minutes Played : 0
# Player ID : 5595
# Num Minutes Played : 0
# Player ID : 15477
# Num Minutes Played : 17
# Player ID : 27163
# Num Minutes Played : 0
# Player ID : 135271
# Num Minutes Played : 0
# Player ID : 3957
# Num Minutes Played : 45
# Player ID : 5592
# Num Minutes Played : 0
# Player ID : 132271
# Num Minutes Played : 0
# Player ID : 184468
# Num Minutes Played : 0
# Player ID : 8064
# Num Minutes Played : 0
# Player ID : 16015
# Num Minutes Played : 87
# Player ID : 3684
# Num Minutes Played : 0
# Player ID : 50497
# Num Minutes Played : 0
# Player ID : 9922
# Num Minutes Played : 141
# Player ID : 11187
# Num Minutes Played : 84
# Player ID : 11846
# Num Minutes Played : 197
# Player ID : 12365
# Num Minutes Played : 197
# Player ID : 12770
# Num Minutes Played : 85
# Player ID : 15958
# Num Minutes Played : 197
# Player ID : 16120
# Num Minutes Played : 105
# Player ID : 16459
# Num Minutes Played : 102
# Player ID : 23640
# Num Minutes Played : 133
# Player ID : 23828
# Num Minutes Played : 197
# Player ID : 24024
# Num Minutes Played : 182
# Player ID : 26348
# Num Minutes Played : 0
# Player ID : 29758
# Num Minutes Played : 87
# Player ID : 31684
# Num Minutes Played : 95
# Player ID : 44703
# Num Minutes Played : 197
# Player ID : 133229
# Num Minutes Played : 71
# Player ID : 3067
# Num Minutes Played : 0
# Player ID : 3247
# Num Minutes Played : 0
# Player ID : 25154
# Num Minutes Played : 0
# Player ID : 7551
# Num Minutes Played : 0
# Player ID : 10530
# Num Minutes Played : 0
# Player ID : 33813
# Num Minutes Played : 0
# Player ID : 74588
# Num Minutes Played : 0
# Player ID : 5476
# Num Minutes Played : 0
# Player ID : 5484
# Num Minutes Played : 0
# Player ID : 9430
# Num Minutes Played : 0
# Player ID : 33572
# Num Minutes Played : 0
# Player ID : 6806
# Num Minutes Played : 17
# Player ID : 15971
# Num Minutes Played : 0
# Player ID : 5220
# Num Minutes Played : 223
# Player ID : 5224
# Num Minutes Played : 98
# Player ID : 5226
# Num Minutes Played : 223
# Player ID : 5227
# Num Minutes Played : 19
# Player ID : 5228
# Num Minutes Played : 223
# Player ID : 5230
# Num Minutes Played : 196
# Player ID : 5231
# Num Minutes Played : 35
# Player ID : 5235
# Num Minutes Played : 106
# Player ID : 5240
# Num Minutes Played : 0
# Player ID : 5720
# Num Minutes Played : 182
# Player ID : 5722
# Num Minutes Played : 158
# Player ID : 23874
# Num Minutes Played : 151
# Player ID : 124161
# Num Minutes Played : 68
# Player ID : 124167
# Num Minutes Played : 171
# Player ID : 125818
# Num Minutes Played : 65
# Player ID : 326758
# Num Minutes Played : 0
# Player ID : 9036
# Num Minutes Played : 0
# Player ID : 16252
# Num Minutes Played : 0
# Player ID : 3543
# Num Minutes Played : 0
# Player ID : 7153
# Num Minutes Played : 0
# Player ID : 7345
# Num Minutes Played : 0
# Player ID : 17592
# Num Minutes Played : 0
# Player ID : 5647
# Num Minutes Played : 0
# Player ID : 6347
# Num Minutes Played : 0
# Player ID : 25582
# Num Minutes Played : 0
# Player ID : 35592
# Num Minutes Played : 70
# Player ID : 102816
# Num Minutes Played : 0
# Player ID : 9914
# Num Minutes Played : 99
# Player ID : 10931
# Num Minutes Played : 85
# Player ID : 5222
# Num Minutes Played : 45
# Player ID : 5239
# Num Minutes Played : 45
# Player ID : 125823
# Num Minutes Played : 98
# Player ID : 3308
# Num Minutes Played : 147
# Player ID : 3616
# Num Minutes Played : 37
# Player ID : 23538
# Num Minutes Played : 0
# Player ID : 124175
# Num Minutes Played : 0
# Player ID : 16275
# Num Minutes Played : 0
# Player ID : 23363
# Num Minutes Played : 0
# Player ID : 99479
# Num Minutes Played : 0
# Player ID : 5218
# Num Minutes Played : 0
# Player ID : 143854
# Num Minutes Played : 0
# Player ID : 82257
# Num Minutes Played : 0
# Player ID : 3664
# Num Minutes Played : 0
# Player ID : 6892
# Num Minutes Played : 0
# Player ID : 5527
# Num Minutes Played : 0
# Player ID : 5534
# Num Minutes Played : 0
# Player ID : 50988
# Num Minutes Played : 0
# =================================================================

# %%
def construct_maps_player_id_with_vaep_value():
    for competition_id, season_id in list(MAPS_COMPETITION_CONTAINS_360_DATA.keys()):
        games_df = api.games(competition_id, season_id)
        for _, row in games_df.iterrows():
            # Looking for player ids for each home team id and away team id
            players_df = api.players(row['game_id'])
            list_player_ids_home_team = pd.Series(players_df[players_df['team_id'] == row['home_team_id']]['player_id']).tolist()
            list_player_ids_away_team = pd.Series(players_df[players_df['team_id'] == row['away_team_id']]['player_id']).tolist()
            
            # Loads event value
            this_game_events_df = api.events(row['game_id'], load_360=True)
            
            # Checkpoint 1 : Loads vaep value for home team id
            this_game_events_df_home_team = spadl.add_names(convert_to_actions_statsbomb(this_game_events_df, row['home_team_id']))
            this_game_events_df_home_team['vaep_value'] = process_vaep_algorithm(this_game_events_df_home_team, row['home_team_id'])
            this_game_events_df_home_team = this_game_events_df_home_team[this_game_events_df_home_team['type_id'].isin(ALL_TYPE_IDS_FROM_MODELS)]
            player_id_and_vaep_value_df = this_game_events_df_home_team.groupby('player_id')['vaep_value'].sum()
            for player_id in list_player_ids_home_team:
                vaep_value = player_id_and_vaep_value_df[player_id] if player_id in player_id_and_vaep_value_df.index else 0
                MAPS_PLAYER_ID_WITH_VAEP_VALUE[(competition_id, season_id)] \
                    [player_id]["total_vaep_value"] += vaep_value
            
            # Checkpoint 2 : Loads vaep value for away team id
            this_game_events_df_away_team = spadl.add_names(convert_to_actions_statsbomb(this_game_events_df, row['away_team_id']))
            this_game_events_df_away_team['vaep_value'] = process_vaep_algorithm(this_game_events_df_away_team, row['away_team_id'])
            this_game_events_df_away_team = this_game_events_df_away_team[this_game_events_df_away_team['type_id'].isin(ALL_TYPE_IDS_FROM_MODELS)]
            player_id_and_vaep_value_df = this_game_events_df_away_team.groupby('player_id')['vaep_value'].sum()
            for player_id in list_player_ids_away_team:
                vaep_value = player_id_and_vaep_value_df[player_id] if player_id in player_id_and_vaep_value_df.index else 0
                MAPS_PLAYER_ID_WITH_VAEP_VALUE[(competition_id, season_id)] \
                    [player_id]["total_vaep_value"] += vaep_value

# %%
# COMMENT IT IF VAEP PLAYER RANKING ALREADY LOADED
construct_maps_player_id_with_vaep_value()
for competition_id, season_id in list(MAPS_PLAYER_ID_WITH_VAEP_VALUE.keys()):
    print("Competition Name : ", MAPS_COMPETITION_CONTAINS_360_DATA[(competition_id, season_id)])
    for player_id in list(MAPS_PLAYER_ID_WITH_VAEP_VALUE[(competition_id, season_id)].keys()):
        print(f'Player ID : {player_id}')
        print(f'Total VAEP Value : {MAPS_PLAYER_ID_WITH_VAEP_VALUE[(competition_id, season_id)][player_id]["total_vaep_value"]}')
    print("=================================================================")
# Out:
# Competition Name :  UEFA Euro 2020
# Player ID : 3477
# Total VAEP Value : -2.4294506391315274
# Player ID : 3957
# Total VAEP Value : -0.061565526795675396
# Player ID : 4353
# Total VAEP Value : 1.1498602606679924
# Player ID : 5199
# Total VAEP Value : 0.04178300540525015
# Player ID : 5203
# Total VAEP Value : -0.5599734040133394
# Player ID : 5208
# Total VAEP Value : -0.6572151785075898
# Player ID : 5211
# Total VAEP Value : 1.2229639628540099
# Player ID : 6685
# Total VAEP Value : 0.16937002078432262
# Player ID : 6720
# Total VAEP Value : 1.0363901136579443
# Player ID : 6748
# Total VAEP Value : 1.0472577069749605
# Player ID : 6765
# Total VAEP Value : 0.030629822838841858
# Player ID : 6766
# Total VAEP Value : -1.3081604695716336
# Player ID : 6840
# Total VAEP Value : -0.0034367583684797864
# Player ID : 6892
# Total VAEP Value : 1.0076755252912335
# Player ID : 11748
# Total VAEP Value : 1.0002108184280587
# Player ID : 16532
# Total VAEP Value : -0.6787866749481954
# Player ID : 30486
# Total VAEP Value : 0.49685279375353275
# Player ID : 3533
# Total VAEP Value : 0.18327307210438448
# Player ID : 5537
# Total VAEP Value : -1.9513502166591472
# Player ID : 5538
# Total VAEP Value : 0.03253080668309849
# Player ID : 5543
# Total VAEP Value : 0.6108166846897802
# Player ID : 5544
# Total VAEP Value : -0.6550824351724936
# Player ID : 5545
# Total VAEP Value : 0.5437270855222778
# Player ID : 5548
# Total VAEP Value : 0.08010998118516
# Player ID : 5549
# Total VAEP Value : -3.237795453982425
# Player ID : 5550
# Total VAEP Value : 0.05600637890165672
# Player ID : 5834
# Total VAEP Value : -1.52405661354528
# Player ID : 6983
# Total VAEP Value : 0.14320914325435297
# Player ID : 7796
# Total VAEP Value : -0.05557984793813375
# Player ID : 8814
# Total VAEP Value : 0.0250774111273131
# Player ID : 16022
# Total VAEP Value : 0.23149519876460545
# Player ID : 16026
# Total VAEP Value : 0.010867334264730744
# Player ID : 16027
# Total VAEP Value : 0.004399575936986366
# Player ID : 30401
# Total VAEP Value : -2.3582323742875353
# Player ID : 3570
# Total VAEP Value : 1.2995934353737315
# Player ID : 3815
# Total VAEP Value : -0.06909283521508769
# Player ID : 3959
# Total VAEP Value : 1.08692392974217
# Player ID : 4447
# Total VAEP Value : 0.13871798534250956
# Player ID : 5524
# Total VAEP Value : 0.1294300842073426
# Player ID : 5527
# Total VAEP Value : 0.9960535727611841
# Player ID : 5534
# Total VAEP Value : 0.9703446725100093
# Player ID : 5536
# Total VAEP Value : 0.05423227615528958
# Player ID : 5732
# Total VAEP Value : 0.07668167523297598
# Player ID : 6302
# Total VAEP Value : -0.2900538532394421
# Player ID : 6797
# Total VAEP Value : 0.058266011608338886
# Player ID : 7097
# Total VAEP Value : 0.2648384424519463
# Player ID : 8815
# Total VAEP Value : 0.9969368535439571
# Player ID : 16554
# Total VAEP Value : 1.045617383138051
# Player ID : 18722
# Total VAEP Value : 0.1126516265239843
# Player ID : 24443
# Total VAEP Value : 0.9983686727950953
# Player ID : 5170
# Total VAEP Value : 0.014430653352974332
# Player ID : 5171
# Total VAEP Value : -0.011880078534886707
# Player ID : 5177
# Total VAEP Value : -0.20812072241733404
# Player ID : 5179
# Total VAEP Value : 0.02045765402908728
# Player ID : 5195
# Total VAEP Value : 0.08869181472985066
# Player ID : 5677
# Total VAEP Value : -0.0035490304599079536
# Player ID : 6299
# Total VAEP Value : 0.05088957517727977
# Player ID : 15545
# Total VAEP Value : 0.050419476010574726
# Player ID : 16583
# Total VAEP Value : 0.015920418457426422
# Player ID : 18734
# Total VAEP Value : 0.05998389971500728
# Player ID : 20845
# Total VAEP Value : 0.1211496727373742
# Player ID : 21298
# Total VAEP Value : -0.024032423078097054
# Player ID : 31917
# Total VAEP Value : 0.020365405285701854
# Player ID : 38178
# Total VAEP Value : 0.028828243375755847
# Player ID : 39273
# Total VAEP Value : 0.961144520738344
# Player ID : 3086
# Total VAEP Value : -0.5582036857813364
# Player ID : 3517
# Total VAEP Value : -0.011802112203440629
# Player ID : 3853
# Total VAEP Value : 0.9548274479966494
# Player ID : 4567
# Total VAEP Value : -0.004423389644216513
# Player ID : 4774
# Total VAEP Value : -0.0306698481181229
# Player ID : 4934
# Total VAEP Value : -0.003822727514489088
# Player ID : 6399
# Total VAEP Value : 1.1974108361300981
# Player ID : 9540
# Total VAEP Value : 0.04095889314703527
# Player ID : 9914
# Total VAEP Value : 0.028151340686235926
# Player ID : 10928
# Total VAEP Value : 0.0032740228343755007
# Player ID : 10931
# Total VAEP Value : 0.9601538884962793
# Player ID : 11250
# Total VAEP Value : -0.04288052844276535
# Player ID : 11252
# Total VAEP Value : 0.09166742988600163
# Player ID : 22074
# Total VAEP Value : 0.07682292951540148
# Player ID : 33144
# Total VAEP Value : 0
# Player ID : 34794
# Total VAEP Value : -0.01688342182751512
# Player ID : 3166
# Total VAEP Value : 0.3278555835490806
# Player ID : 4355
# Total VAEP Value : 0.026907981572549033
# Player ID : 6993
# Total VAEP Value : 0.861278333408336
# Player ID : 7002
# Total VAEP Value : 0.00020155044876446482
# Player ID : 7024
# Total VAEP Value : 1.1486341482596352
# Player ID : 7036
# Total VAEP Value : 0.9471356279636893
# Player ID : 7119
# Total VAEP Value : 1.026773709070767
# Player ID : 7156
# Total VAEP Value : 0.5542586233609654
# Player ID : 7173
# Total VAEP Value : 0.15620811871763274
# Player ID : 7469
# Total VAEP Value : -0.0002193385735154152
# Player ID : 7471
# Total VAEP Value : -1.3814548576583083
# Player ID : 7480
# Total VAEP Value : -0.0055730658350512385
# Player ID : 7777
# Total VAEP Value : 0.02271358221519315
# Player ID : 11601
# Total VAEP Value : 0.05347193156103458
# Player ID : 25048
# Total VAEP Value : 0.0012136473742430098
# Player ID : 30707
# Total VAEP Value : 0.004819575580768287
# Player ID : 6954
# Total VAEP Value : 0.030549946786322835
# Player ID : 7037
# Total VAEP Value : 1.8907610055980513
# Player ID : 7038
# Total VAEP Value : -0.7181360833001004
# Player ID : 7131
# Total VAEP Value : -0.5149585497483482
# Player ID : 7788
# Total VAEP Value : 0.7812956036586911
# Player ID : 8181
# Total VAEP Value : 0.08543433191971417
# Player ID : 11514
# Total VAEP Value : 1.0367366827204023
# Player ID : 31953
# Total VAEP Value : 0.877355720340347
# Player ID : 3702
# Total VAEP Value : 0.8350044569415331
# Player ID : 5611
# Total VAEP Value : 0
# Player ID : 5612
# Total VAEP Value : 0.0797228202354745
# Player ID : 5613
# Total VAEP Value : -0.0234634095832007
# Player ID : 5617
# Total VAEP Value : 0.07862640515668318
# Player ID : 5621
# Total VAEP Value : 0.020053874634868407
# Player ID : 5622
# Total VAEP Value : -0.032535725897105294
# Player ID : 5624
# Total VAEP Value : 0.12538319564191625
# Player ID : 5625
# Total VAEP Value : -0.6290000821026974
# Player ID : 6358
# Total VAEP Value : 0.012085011760063935
# Player ID : 8552
# Total VAEP Value : -0.032712039230318624
# Player ID : 8819
# Total VAEP Value : 1.8875001258784323
# Player ID : 11098
# Total VAEP Value : 0.049662878052913584
# Player ID : 20871
# Total VAEP Value : 0.01300103789253626
# Player ID : 23444
# Total VAEP Value : -0.00088829231026466
# Player ID : 26875
# Total VAEP Value : -0.0021413960721474723
# Player ID : 3711
# Total VAEP Value : -0.00428657396514609
# Player ID : 4421
# Total VAEP Value : 0.02327783351756807
# Player ID : 6990
# Total VAEP Value : 0.01978112718461489
# Player ID : 7025
# Total VAEP Value : 0.008840990352837252
# Player ID : 7975
# Total VAEP Value : 0.07731500617956044
# Player ID : 8967
# Total VAEP Value : 0.007625388840097003
# Player ID : 9722
# Total VAEP Value : 0.05212722093165212
# Player ID : 10919
# Total VAEP Value : 0.12955695878008555
# Player ID : 10922
# Total VAEP Value : 0.016956327941443305
# Player ID : 10927
# Total VAEP Value : 0.0007090589060680941
# Player ID : 11383
# Total VAEP Value : 0.021713342393923085
# Player ID : 16041
# Total VAEP Value : 0.00023444872931577265
# Player ID : 16307
# Total VAEP Value : 0.013462164541124366
# Player ID : 16879
# Total VAEP Value : 0.015422696553287096
# Player ID : 28044
# Total VAEP Value : -0.017533381214889232
# Player ID : 30397
# Total VAEP Value : 0.05630667063451256
# Player ID : 3168
# Total VAEP Value : 0.9355758658421109
# Player ID : 3193
# Total VAEP Value : 0.08220909536248655
# Player ID : 3593
# Total VAEP Value : 2.4482379061846586
# Player ID : 5204
# Total VAEP Value : 1.0199323036049464
# Player ID : 5205
# Total VAEP Value : 0.028780006357919774
# Player ID : 5206
# Total VAEP Value : 0.05891150113711774
# Player ID : 5207
# Total VAEP Value : 1.6918666686234032
# Player ID : 5209
# Total VAEP Value : -0.009431068134290399
# Player ID : 5214
# Total VAEP Value : 0.012161577618826414
# Player ID : 5218
# Total VAEP Value : 0.007802059286404983
# Player ID : 6374
# Total VAEP Value : -0.07040439338743454
# Player ID : 9929
# Total VAEP Value : 0.057451744583886466
# Player ID : 10327
# Total VAEP Value : -0.06023792004361894
# Player ID : 13621
# Total VAEP Value : 0.030392616401513806
# Player ID : 20016
# Total VAEP Value : 0.07982680874374637
# Player ID : 3053
# Total VAEP Value : 0.007002855832070054
# Player ID : 3167
# Total VAEP Value : 0.004188823869299085
# Player ID : 3493
# Total VAEP Value : -0.017157153677544557
# Player ID : 5562
# Total VAEP Value : 0.0025528530659357784
# Player ID : 5570
# Total VAEP Value : 0.06339356564330956
# Player ID : 5572
# Total VAEP Value : -0.398435565474756
# Player ID : 5574
# Total VAEP Value : 0.08622969634234323
# Player ID : 5579
# Total VAEP Value : -0.7149143286605977
# Player ID : 6322
# Total VAEP Value : 0.002263639060402056
# Player ID : 6324
# Total VAEP Value : 0.019933291430788813
# Player ID : 6985
# Total VAEP Value : 0.03491764285536192
# Player ID : 8400
# Total VAEP Value : -0.0232133037834501
# Player ID : 8525
# Total VAEP Value : -0.011093573848484084
# Player ID : 8808
# Total VAEP Value : 0.12121660907178011
# Player ID : 8966
# Total VAEP Value : 0.7547360546495838
# Player ID : 10287
# Total VAEP Value : 0.0629785018036273
# Player ID : 9927
# Total VAEP Value : -0.0010081363798235543
# Player ID : 11173
# Total VAEP Value : 0.012036847554554697
# Player ID : 12169
# Total VAEP Value : -0.014215344141121022
# Player ID : 16028
# Total VAEP Value : 0.014824788413534407
# Player ID : 2999
# Total VAEP Value : -0.6834591841515926
# Player ID : 3009
# Total VAEP Value : -1.6005336081106858
# Player ID : 3026
# Total VAEP Value : -0.02867746805986826
# Player ID : 3091
# Total VAEP Value : -0.010296746309904847
# Player ID : 3099
# Total VAEP Value : 0.21090597605598305
# Player ID : 3961
# Total VAEP Value : -0.8569540530634185
# Player ID : 4445
# Total VAEP Value : 0.04257986228549271
# Player ID : 5480
# Total VAEP Value : 0.9621472128856112
# Player ID : 5484
# Total VAEP Value : -0.018549730146332877
# Player ID : 5485
# Total VAEP Value : 0.015299309620786516
# Player ID : 5487
# Total VAEP Value : 0.3909242200961671
# Player ID : 6849
# Total VAEP Value : -0.031927481049933704
# Player ID : 8217
# Total VAEP Value : 0.9740631476743147
# Player ID : 19677
# Total VAEP Value : -0.6193191717447685
# Player ID : 20004
# Total VAEP Value : 2.1392689290278444
# Player ID : 4767
# Total VAEP Value : -0.02137031800157274
# Player ID : 6971
# Total VAEP Value : 0.1194920800953696
# Player ID : 7039
# Total VAEP Value : 0.02505041645417805
# Player ID : 8541
# Total VAEP Value : 0.01216146799197304
# Player ID : 8963
# Total VAEP Value : 0.0010877935983444331
# Player ID : 10349
# Total VAEP Value : -0.02194316440363764
# Player ID : 10826
# Total VAEP Value : 0.025124472507741302
# Player ID : 11086
# Total VAEP Value : 0.07331270561917336
# Player ID : 11088
# Total VAEP Value : 0.03341486408316996
# Player ID : 12293
# Total VAEP Value : 0.9282902053273574
# Player ID : 12555
# Total VAEP Value : 0.015031377937702928
# Player ID : 21567
# Total VAEP Value : 0.005137301708600717
# Player ID : 23558
# Total VAEP Value : 0.02980728878173977
# Player ID : 29989
# Total VAEP Value : 0.004104985877347644
# Player ID : 30311
# Total VAEP Value : 0.014083096550166374
# Player ID : 30357
# Total VAEP Value : -0.6321028109541658
# Player ID : 31042
# Total VAEP Value : 0.006507083195174346
# Player ID : 3500
# Total VAEP Value : 2.891013391209526
# Player ID : 8286
# Total VAEP Value : 0.012714940273326647
# Player ID : 3034
# Total VAEP Value : 0.012914546285173856
# Player ID : 4626
# Total VAEP Value : 0.020943193396306015
# Player ID : 4673
# Total VAEP Value : -0.007509879970712063
# Player ID : 5660
# Total VAEP Value : -0.8258279771616799
# Player ID : 5668
# Total VAEP Value : 0.9360718098832876
# Player ID : 5669
# Total VAEP Value : -0.0071310481580439955
# Player ID : 5673
# Total VAEP Value : 0.9488111773052879
# Player ID : 7964
# Total VAEP Value : 0.012146763274358818
# Player ID : 7979
# Total VAEP Value : 0.044129105473984964
# Player ID : 8737
# Total VAEP Value : 0.006295474093349185
# Player ID : 8836
# Total VAEP Value : 0.024331299335244694
# Player ID : 9622
# Total VAEP Value : 0.03190373265351809
# Player ID : 26718
# Total VAEP Value : 0.0008255906323029194
# Player ID : 29480
# Total VAEP Value : 0.056315322741284035
# Player ID : 30739
# Total VAEP Value : 0.0006669988215435296
# Player ID : 6655
# Total VAEP Value : 0.010273623609464266
# Player ID : 4870
# Total VAEP Value : 0.019250610092058196
# Player ID : 4875
# Total VAEP Value : 0.1562274339958094
# Player ID : 7044
# Total VAEP Value : 0.28181699820381756
# Player ID : 7801
# Total VAEP Value : 0.045639831963853794
# Player ID : 8095
# Total VAEP Value : -0.043342526152628125
# Player ID : 8579
# Total VAEP Value : 1.4568263248438598
# Player ID : 11541
# Total VAEP Value : 0.010594198050966952
# Player ID : 13197
# Total VAEP Value : 0.01744793975558423
# Player ID : 16037
# Total VAEP Value : 0.029701189592742594
# Player ID : 16469
# Total VAEP Value : 0.12201217008805543
# Player ID : 16472
# Total VAEP Value : 0.9170590801149956
# Player ID : 16570
# Total VAEP Value : 0.9580372772643386
# Player ID : 23452
# Total VAEP Value : 0.02797197977270116
# Player ID : 23454
# Total VAEP Value : 0.18253152119541483
# Player ID : 28239
# Total VAEP Value : 0.005812509090901585
# Player ID : 30328
# Total VAEP Value : 0.2595868781390891
# Player ID : 3441
# Total VAEP Value : 1.0060776403515774
# Player ID : 3471
# Total VAEP Value : 0.030965049994847504
# Player ID : 5456
# Total VAEP Value : 0.09201578802822041
# Player ID : 5460
# Total VAEP Value : 0.06738355466040957
# Player ID : 5461
# Total VAEP Value : -0.007973274790856522
# Player ID : 5463
# Total VAEP Value : 0.8051115654634486
# Player ID : 5465
# Total VAEP Value : 0.061345557933236705
# Player ID : 5468
# Total VAEP Value : 0.016685801161656855
# Player ID : 5469
# Total VAEP Value : 1.092102791839352
# Player ID : 5474
# Total VAEP Value : 1.2598394063252272
# Player ID : 7693
# Total VAEP Value : -0.0169235517969355
# Player ID : 8946
# Total VAEP Value : 0.011924139169423142
# Player ID : 16531
# Total VAEP Value : -0.8722966208370053
# Player ID : 28368
# Total VAEP Value : -0.00231871145660989
# Player ID : 33018
# Total VAEP Value : 0.0966353304365839
# Player ID : 3325
# Total VAEP Value : 0.9769420391221502
# Player ID : 3969
# Total VAEP Value : 0.05811706853728538
# Player ID : 8220
# Total VAEP Value : 0.07478037690634665
# Player ID : 8307
# Total VAEP Value : -0.06278722846718665
# Player ID : 8309
# Total VAEP Value : 0.09230973689955135
# Player ID : 8506
# Total VAEP Value : 0.042609089451616455
# Player ID : 8513
# Total VAEP Value : 0.00042938235492329113
# Player ID : 8518
# Total VAEP Value : 0.9999308201413442
# Player ID : 8769
# Total VAEP Value : 0.037980336524924496
# Player ID : 8777
# Total VAEP Value : 0.22941602352875634
# Player ID : 8779
# Total VAEP Value : 0.07356179281168806
# Player ID : 8931
# Total VAEP Value : 0.03321203930318006
# Player ID : 18762
# Total VAEP Value : 0.04063233850138204
# Player ID : 20037
# Total VAEP Value : -0.0011831624869955704
# Player ID : 21532
# Total VAEP Value : 0.14093418325819584
# Player ID : 24977
# Total VAEP Value : 0.15379111653328437
# Player ID : 4713
# Total VAEP Value : 0.1785554281068703
# Player ID : 6782
# Total VAEP Value : 2.0119588941342954
# Player ID : 7146
# Total VAEP Value : 0.25203040642736596
# Player ID : 10592
# Total VAEP Value : 0.03213817057530832
# Player ID : 16535
# Total VAEP Value : 0.9696293345623417
# Player ID : 16629
# Total VAEP Value : 0.008766775819822215
# Player ID : 16740
# Total VAEP Value : 0.01710637443102314
# Player ID : 18879
# Total VAEP Value : 0.06359726839764335
# Player ID : 21397
# Total VAEP Value : 0.09204326211147418
# Player ID : 30512
# Total VAEP Value : 0.06605204175320978
# Player ID : 30644
# Total VAEP Value : 0.008997043986710196
# Player ID : 44229
# Total VAEP Value : -0.00943561480835342
# Player ID : 44962
# Total VAEP Value : 0
# Player ID : 46906
# Total VAEP Value : 0.013794386979498086
# Player ID : 46915
# Total VAEP Value : 0.011196930799997062
# Player ID : 6964
# Total VAEP Value : 0.05786072277442145
# Player ID : 8247
# Total VAEP Value : 0.004399537632707506
# Player ID : 4809
# Total VAEP Value : 0.0022972465594648384
# Player ID : 27622
# Total VAEP Value : 0.0010579899317235686
# Player ID : 3205
# Total VAEP Value : 0.9257136932210415
# Player ID : 3233
# Total VAEP Value : 2.0808153752886938
# Player ID : 3244
# Total VAEP Value : 0.35244707727360947
# Player ID : 3308
# Total VAEP Value : 0.0034137797001676518
# Player ID : 3318
# Total VAEP Value : -1.5670204598045299
# Player ID : 3336
# Total VAEP Value : 0.25719689517202415
# Player ID : 3382
# Total VAEP Value : 0.5476760861338335
# Player ID : 3468
# Total VAEP Value : 0.06720157434574503
# Player ID : 3470
# Total VAEP Value : 0.00012071859600837342
# Player ID : 3532
# Total VAEP Value : 0.0514170196829582
# Player ID : 3943
# Total VAEP Value : 0.0403662511434959
# Player ID : 4706
# Total VAEP Value : 0.7921921703759836
# Player ID : 7843
# Total VAEP Value : -0.040822787325851095
# Player ID : 10955
# Total VAEP Value : 0.7535903419357519
# Player ID : 12423
# Total VAEP Value : 1.1024425316473074
# Player ID : 30714
# Total VAEP Value : 0.0022002859659551177
# Player ID : 3575
# Total VAEP Value : 0.23997960119777417
# Player ID : 8830
# Total VAEP Value : 0.6986946801657723
# Player ID : 16311
# Total VAEP Value : 0.015621548152921605
# Player ID : 16509
# Total VAEP Value : -0.0064173933260462945
# Player ID : 16514
# Total VAEP Value : 0.05548966606238537
# Player ID : 18617
# Total VAEP Value : 0.038547085238860745
# Player ID : 18618
# Total VAEP Value : -0.013868264678421838
# Player ID : 20827
# Total VAEP Value : 0.9424250406900683
# Player ID : 21294
# Total VAEP Value : 1.9531229816834639
# Player ID : 22243
# Total VAEP Value : 0.04640655664024962
# Player ID : 23649
# Total VAEP Value : 0.1233342586388062
# Player ID : 31900
# Total VAEP Value : 0.14248733241265654
# Player ID : 39136
# Total VAEP Value : 0.8923793006156302
# Player ID : 2988
# Total VAEP Value : 0.40273544661888583
# Player ID : 3311
# Total VAEP Value : 0.023952498899234342
# Player ID : 3321
# Total VAEP Value : 0.22377663842962647
# Player ID : 3567
# Total VAEP Value : 0.751137187173299
# Player ID : 7745
# Total VAEP Value : 0.6405800244247075
# Player ID : 7787
# Total VAEP Value : 1.1143281758795638
# Player ID : 7829
# Total VAEP Value : 0.054363945904697175
# Player ID : 8069
# Total VAEP Value : 0.050147379204645404
# Player ID : 8118
# Total VAEP Value : 1.7452926145670062
# Player ID : 8125
# Total VAEP Value : -0.012484623150157859
# Player ID : 13360
# Total VAEP Value : -0.1960201524416334
# Player ID : 15582
# Total VAEP Value : 0.056137914696591906
# Player ID : 20201
# Total VAEP Value : 0.2036488746634859
# Player ID : 20750
# Total VAEP Value : 0.0014027995857759379
# Player ID : 21809
# Total VAEP Value : 0.9148409406952851
# Player ID : 23230
# Total VAEP Value : 0.08235248029814102
# Player ID : 30262
# Total VAEP Value : 0.0015194859879557043
# Player ID : 30322
# Total VAEP Value : -0.0026302865080651827
# Player ID : 41836
# Total VAEP Value : -0.00395137928717304
# Player ID : 9638
# Total VAEP Value : 0.006457137902543764
# Player ID : 22084
# Total VAEP Value : -0.6490399729854966
# Player ID : 5557
# Total VAEP Value : 0.8987796213186812
# Player ID : 39565
# Total VAEP Value : 0.2315651304925268
# Player ID : 7966
# Total VAEP Value : -0.004876275095739402
# Player ID : 22818
# Total VAEP Value : 0.014186999513185583
# Player ID : 11000
# Total VAEP Value : 0.019443557241174858
# Player ID : 16557
# Total VAEP Value : -0.48578979998817395
# Player ID : 18881
# Total VAEP Value : 0.006496648013126105
# Player ID : 23725
# Total VAEP Value : 0.00026816653553396463
# Player ID : 25079
# Total VAEP Value : -0.040629769224324264
# Player ID : 6596
# Total VAEP Value : 0.014762717810299364
# Player ID : 6307
# Total VAEP Value : 0.03590678098225908
# Player ID : 8654
# Total VAEP Value : 0.9808688012999482
# Player ID : 11603
# Total VAEP Value : 0.004593631045281654
# Player ID : 16527
# Total VAEP Value : 0.061974541858944576
# Player ID : 29163
# Total VAEP Value : 1.0065704755015759
# Player ID : 12041
# Total VAEP Value : 0.010723048937506974
# Player ID : 2954
# Total VAEP Value : 0.2061287097640161
# Player ID : 3077
# Total VAEP Value : -0.07555949207107915
# Player ID : 3089
# Total VAEP Value : 1.5111292731317008
# Player ID : 3176
# Total VAEP Value : 0.3545303765931749
# Player ID : 3289
# Total VAEP Value : 2.131881706859554
# Player ID : 3509
# Total VAEP Value : 0.003538181939802598
# Player ID : 3621
# Total VAEP Value : 0.08419195132319146
# Player ID : 5630
# Total VAEP Value : -0.04316947576262464
# Player ID : 5632
# Total VAEP Value : 0.1631718537873894
# Player ID : 5633
# Total VAEP Value : -0.0025090910457947757
# Player ID : 5642
# Total VAEP Value : 0.05712379955639335
# Player ID : 6331
# Total VAEP Value : 0.03144313139637234
# Player ID : 6332
# Total VAEP Value : 0.9613440721323059
# Player ID : 20005
# Total VAEP Value : 1.2976347946896567
# Player ID : 9086
# Total VAEP Value : 0.9364596155064646
# Player ID : 9164
# Total VAEP Value : -0.0006564226350747049
# Player ID : 11281
# Total VAEP Value : 0.00718039601269993
# Player ID : 11396
# Total VAEP Value : -0.14412526147134486
# Player ID : 8215
# Total VAEP Value : -0.0007605166028952226
# Player ID : 7162
# Total VAEP Value : -0.0007747436957288301
# Player ID : 8407
# Total VAEP Value : 1.031780825838723
# Player ID : 8509
# Total VAEP Value : 0.025501981923298445
# Player ID : 8524
# Total VAEP Value : 0.07087235578728723
# Player ID : 10794
# Total VAEP Value : 0.01022182053202414
# Player ID : 11268
# Total VAEP Value : 0.46140107443170564
# Player ID : 12723
# Total VAEP Value : 0.8277023397204175
# Player ID : 16502
# Total VAEP Value : 0.22528388482896844
# Player ID : 16741
# Total VAEP Value : -0.0016511468693352072
# Player ID : 19316
# Total VAEP Value : 0.8930162744836707
# Player ID : 22565
# Total VAEP Value : -0.005595669492322486
# Player ID : 31887
# Total VAEP Value : -0.014566369663953083
# Player ID : 42822
# Total VAEP Value : -0.7851593722243706
# Player ID : 46376
# Total VAEP Value : 0.12919218085880857
# Player ID : 47435
# Total VAEP Value : 0.06059707647727919
# Player ID : 11127
# Total VAEP Value : 0.00792411618749611
# Player ID : 3581
# Total VAEP Value : 0.025064556153665762
# Player ID : 3620
# Total VAEP Value : 0.002891519112381502
# Player ID : 3655
# Total VAEP Value : 0.0147579734766623
# Player ID : 9048
# Total VAEP Value : -0.006645436431426788
# Player ID : 9466
# Total VAEP Value : 0.021342521969927475
# Player ID : 9481
# Total VAEP Value : -0.0017804950621211901
# Player ID : 9645
# Total VAEP Value : 0.05471574243347277
# Player ID : 9974
# Total VAEP Value : 0.10191567124275025
# Player ID : 10002
# Total VAEP Value : -0.012989951617782936
# Player ID : 10285
# Total VAEP Value : 0.8941078878469852
# Player ID : 10534
# Total VAEP Value : 0.2034573392411403
# Player ID : 10540
# Total VAEP Value : 0.024383001367823454
# Player ID : 29571
# Total VAEP Value : 0.014017549787240569
# Player ID : 37338
# Total VAEP Value : -0.006123401337390533
# Player ID : 43563
# Total VAEP Value : -0.0024942384370660875
# Player ID : 3323
# Total VAEP Value : 0.7024488909955835
# Player ID : 20355
# Total VAEP Value : -0.00023971412156242877
# Player ID : 3380
# Total VAEP Value : 0.002822843613103032
# Player ID : 3457
# Total VAEP Value : 0.0004135703347856179
# Player ID : 4831
# Total VAEP Value : 0.005278495424136054
# Player ID : 5639
# Total VAEP Value : 0.021580155793344602
# Player ID : 13116
# Total VAEP Value : -0.03608920741589827
# Player ID : 16281
# Total VAEP Value : -3.566232044249773e-05
# Player ID : 16559
# Total VAEP Value : -0.0008018889202503487
# Player ID : 23650
# Total VAEP Value : 0.0013244451884020236
# Player ID : 8056
# Total VAEP Value : 0.010833790089236572
# Player ID : 8667
# Total VAEP Value : 0.015394422072859015
# Player ID : 9476
# Total VAEP Value : 0.004087272827746347
# Player ID : 9725
# Total VAEP Value : 0.09968427813873859
# Player ID : 12148
# Total VAEP Value : -0.0007811440154910088
# Player ID : 12807
# Total VAEP Value : -0.27755043309298344
# Player ID : 13215
# Total VAEP Value : -0.011187236646946985
# Player ID : 15416
# Total VAEP Value : 0.041684996300318744
# Player ID : 16550
# Total VAEP Value : -0.10060826906556031
# Player ID : 24303
# Total VAEP Value : 0.008750617947953288
# Player ID : 24321
# Total VAEP Value : 0.7237639746017521
# Player ID : 24455
# Total VAEP Value : 0.017102138910559006
# Player ID : 24648
# Total VAEP Value : 0.18991427971195662
# Player ID : 26939
# Total VAEP Value : 0.0040169530402636155
# Player ID : 38196
# Total VAEP Value : 0.013963887322461233
# Player ID : 41828
# Total VAEP Value : 0.010727092274464667
# Player ID : 16811
# Total VAEP Value : -0.0009058219202415785
# Player ID : 18735
# Total VAEP Value : 0.04006796007161029
# Player ID : 10832
# Total VAEP Value : 0.0013077647381578572
# Player ID : 28332
# Total VAEP Value : 0.00267631265160162
# Player ID : 8219
# Total VAEP Value : 0.07573899842011589
# Player ID : 16018
# Total VAEP Value : 0.002196165849454701
# Player ID : 21271
# Total VAEP Value : 0.0009309280867455527
# Player ID : 22212
# Total VAEP Value : -0.00044574286221177317
# Player ID : 3245
# Total VAEP Value : -0.012743646526359953
# Player ID : 3604
# Total VAEP Value : -0.7287716601876805
# Player ID : 5476
# Total VAEP Value : -0.005245671100055915
# Player ID : 5477
# Total VAEP Value : 0.003458698687609285
# Player ID : 46378
# Total VAEP Value : -0.001537225085485261
# Player ID : 4354
# Total VAEP Value : -0.016654364496389462
# Player ID : 9550
# Total VAEP Value : 0.0
# Player ID : 31067
# Total VAEP Value : 0.0
# Player ID : 4872
# Total VAEP Value : 0
# Player ID : 46909
# Total VAEP Value : -0.001332051760982722
# Player ID : 46910
# Total VAEP Value : 0.0013855331199010834
# Player ID : 73852
# Total VAEP Value : 0.0003469554503681138
# Player ID : 17042
# Total VAEP Value : -0.01649687775716302
# Player ID : 7015
# Total VAEP Value : 0.008912050614526379
# Player ID : 21261
# Total VAEP Value : 0.0005249901396382484
# Player ID : 16301
# Total VAEP Value : 0.017238718399312347
# Player ID : 4129
# Total VAEP Value : -0.0036559382861014456
# Player ID : 3306
# Total VAEP Value : 0.9874731159579824
# Player ID : 6994
# Total VAEP Value : 0.025857495154923527
# Player ID : 7890
# Total VAEP Value : 0.016635518175462494
# Player ID : 8067
# Total VAEP Value : 0.04507114267471479
# Player ID : 20033
# Total VAEP Value : -0.003635408436821308
# Player ID : 31892
# Total VAEP Value : -0.0011551657298696227
# Player ID : 2972
# Total VAEP Value : -0.7785206218149819
# Player ID : 6826
# Total VAEP Value : 0.0006813697564211907
# Player ID : 9397
# Total VAEP Value : 0.015844032732275082
# Player ID : 22026
# Total VAEP Value : -0.0013147764548193663
# Player ID : 11278
# Total VAEP Value : 0.0047672564833192155
# Player ID : 11280
# Total VAEP Value : -0.0013236360464361496
# Player ID : 3637
# Total VAEP Value : -0.05328891830868088
# Player ID : 5672
# Total VAEP Value : 0.024553875027777394
# Player ID : 16290
# Total VAEP Value : 0.0004309664145694114
# Player ID : 20002
# Total VAEP Value : 0.7839529019620386
# Player ID : 35653
# Total VAEP Value : 0.004149091873841826
# Player ID : 26063
# Total VAEP Value : 0.0
# Player ID : 9621
# Total VAEP Value : 0.015613457220752025
# Player ID : 10536
# Total VAEP Value : -0.0017156384346890263
# Player ID : 11116
# Total VAEP Value : -0.030556175479432568
# Player ID : 12510
# Total VAEP Value : -0.011911409193999134
# Player ID : 31890
# Total VAEP Value : 0.03691408429222065
# Player ID : 32395
# Total VAEP Value : 0.00023850562138250098
# Player ID : 3043
# Total VAEP Value : -5.8866964536719024e-05
# Player ID : 21442
# Total VAEP Value : 0
# Player ID : 11333
# Total VAEP Value : 0.012131779272749554
# Player ID : 6798
# Total VAEP Value : -0.00819957408020855
# Player ID : 18927
# Total VAEP Value : 0.9390312064024329
# Player ID : 27691
# Total VAEP Value : -0.002351790255488595
# Player ID : 6989
# Total VAEP Value : 0.0024715513281989843
# Player ID : 5186
# Total VAEP Value : -0.003172142455696303
# Player ID : 5193
# Total VAEP Value : -0.004760269755934132
# Player ID : 34588
# Total VAEP Value : 0.018523289105360163
# Player ID : 38119
# Total VAEP Value : 0.02943801611309027
# =================================================================
# Competition Name :  FIFA World Cup 2022
# Player ID : 3500
# Total VAEP Value : 0.1005731504628784
# Player ID : 3533
# Total VAEP Value : -0.0580879112767434
# Player ID : 3913
# Total VAEP Value : 0.027542004607312265
# Player ID : 5537
# Total VAEP Value : 0.0822886685928097
# Player ID : 5538
# Total VAEP Value : 0.028118128310779866
# Player ID : 5544
# Total VAEP Value : 1.2823064233889454
# Player ID : 5545
# Total VAEP Value : 0.30776849928042793
# Player ID : 5549
# Total VAEP Value : 0.2842292582054142
# Player ID : 6983
# Total VAEP Value : -0.10399884301477869
# Player ID : 7796
# Total VAEP Value : -0.03037630451945006
# Player ID : 16022
# Total VAEP Value : 0.0009660540090408176
# Player ID : 16026
# Total VAEP Value : -0.8092830260357005
# Player ID : 17974
# Total VAEP Value : 0.1502693213406019
# Player ID : 29006
# Total VAEP Value : 0.004499982151173754
# Player ID : 30401
# Total VAEP Value : -0.005469298168463865
# Player ID : 3831
# Total VAEP Value : 0.20733242449750833
# Player ID : 4269
# Total VAEP Value : 0.9621465480995539
# Player ID : 5589
# Total VAEP Value : 0.20057189199724235
# Player ID : 5591
# Total VAEP Value : -0.04377877208389691
# Player ID : 5603
# Total VAEP Value : -0.02324324341134343
# Player ID : 5833
# Total VAEP Value : 1.0306408512406051e-05
# Player ID : 6318
# Total VAEP Value : -0.10612177676557621
# Player ID : 6319
# Total VAEP Value : 4.406263178680092e-05
# Player ID : 6321
# Total VAEP Value : 0.08799546667978575
# Player ID : 6687
# Total VAEP Value : 0.03950046792488138
# Player ID : 6901
# Total VAEP Value : 0.005515170390935964
# Player ID : 7117
# Total VAEP Value : -0.001356493856292218
# Player ID : 16489
# Total VAEP Value : 0.0018658725730347214
# Player ID : 18015
# Total VAEP Value : -0.024070282852335367
# Player ID : 20600
# Total VAEP Value : 0.06362145694583887
# Player ID : 27719
# Total VAEP Value : -0.04258649382609292
# Player ID : 3090
# Total VAEP Value : 1.0583426383718688
# Player ID : 5503
# Total VAEP Value : -2.262828862387161
# Player ID : 5507
# Total VAEP Value : -0.005561820236835047
# Player ID : 6909
# Total VAEP Value : 0.009594485356046789
# Player ID : 7006
# Total VAEP Value : 0.24267306156434643
# Player ID : 7797
# Total VAEP Value : 2.736719583019749
# Player ID : 11456
# Total VAEP Value : 0.08294965472307514
# Player ID : 19597
# Total VAEP Value : 0.9480844744975911
# Player ID : 20572
# Total VAEP Value : 0.19365750565657436
# Player ID : 27768
# Total VAEP Value : -0.016208670233936573
# Player ID : 27886
# Total VAEP Value : 0.14495990416480709
# Player ID : 28263
# Total VAEP Value : 0.18272296353920958
# Player ID : 28268
# Total VAEP Value : 0.030406893478357233
# Player ID : 29201
# Total VAEP Value : 0.2568079895581832
# Player ID : 29560
# Total VAEP Value : 0.28088469911108405
# Player ID : 38718
# Total VAEP Value : -0.7799085554170001
# Player ID : 3240
# Total VAEP Value : -1.0285372501784877
# Player ID : 3281
# Total VAEP Value : 0.9552618269772211
# Player ID : 5479
# Total VAEP Value : -0.9477373067347798
# Player ID : 5481
# Total VAEP Value : -0.030473408034595195
# Player ID : 5490
# Total VAEP Value : 0.20062318226155185
# Player ID : 8346
# Total VAEP Value : 0.010763767000753433
# Player ID : 8859
# Total VAEP Value : 0.030589345486077946
# Player ID : 9980
# Total VAEP Value : 0.021825885403814027
# Player ID : 15957
# Total VAEP Value : -0.003948374158426304
# Player ID : 22293
# Total VAEP Value : 1.8351690957642859
# Player ID : 28370
# Total VAEP Value : 0.002637764329847414
# Player ID : 33477
# Total VAEP Value : -0.031905146404824336
# Player ID : 33488
# Total VAEP Value : 0.002289365284013911
# Player ID : 33492
# Total VAEP Value : -0.20333132891937566
# Player ID : 33495
# Total VAEP Value : 0.07820046108827228
# Player ID : 227697
# Total VAEP Value : 0.012735548350974568
# Player ID : 3043
# Total VAEP Value : 0.032671891578502255
# Player ID : 3570
# Total VAEP Value : 0.02403241144020285
# Player ID : 3815
# Total VAEP Value : 0.005164336951565929
# Player ID : 3959
# Total VAEP Value : 0.010347649584218743
# Player ID : 4447
# Total VAEP Value : 0.01706334329355741
# Player ID : 5732
# Total VAEP Value : 0.003166268796121585
# Player ID : 6302
# Total VAEP Value : 0.014014427273650654
# Player ID : 8247
# Total VAEP Value : 0.023369341257421183
# Player ID : 16190
# Total VAEP Value : 0.033548121489729965
# Player ID : 16294
# Total VAEP Value : -0.004285322444047779
# Player ID : 16554
# Total VAEP Value : 0.9252430704691506
# Player ID : 17042
# Total VAEP Value : -0.002714232206926681
# Player ID : 18722
# Total VAEP Value : -0.0019405063067097217
# Player ID : 24443
# Total VAEP Value : 0.014631580294008018
# Player ID : 24547
# Total VAEP Value : 0.005948603677097708
# Player ID : 27569
# Total VAEP Value : 0.03307993439375423
# Player ID : 22371
# Total VAEP Value : 0.004420694167492911
# Player ID : 3063
# Total VAEP Value : 1.7857558410851198
# Player ID : 3202
# Total VAEP Value : -0.006216471185325645
# Player ID : 3280
# Total VAEP Value : 0.968838608760052
# Player ID : 3295
# Total VAEP Value : 0.06913648052432109
# Player ID : 4320
# Total VAEP Value : 1.2274678566546076
# Player ID : 4372
# Total VAEP Value : -0.5533724691476659
# Player ID : 5539
# Total VAEP Value : 0.3964030099341703
# Player ID : 5547
# Total VAEP Value : 0.01699425434708246
# Player ID : 6945
# Total VAEP Value : 0.9441270003044337
# Player ID : 9904
# Total VAEP Value : 0.05151921209107968
# Player ID : 10595
# Total VAEP Value : 1.2254086892507985
# Player ID : 18395
# Total VAEP Value : 0.02924782429545303
# Player ID : 22600
# Total VAEP Value : -0.03236225594264397
# Player ID : 25104
# Total VAEP Value : -0.7846145117182227
# Player ID : 25363
# Total VAEP Value : 0.7752032032876741
# Player ID : 29976
# Total VAEP Value : 0.013851771600457141
# Player ID : 7145
# Total VAEP Value : 0.035504212173691485
# Player ID : 7993
# Total VAEP Value : -0.004427671479788842
# Player ID : 30179
# Total VAEP Value : 0.015964981270371936
# Player ID : 3196
# Total VAEP Value : 0.023867805168265477
# Player ID : 3557
# Total VAEP Value : 0.0015706825943198055
# Player ID : 3767
# Total VAEP Value : -0.04503196086443495
# Player ID : 5650
# Total VAEP Value : -0.0022436930739786476
# Player ID : 5651
# Total VAEP Value : 0.0022433237463701516
# Player ID : 5655
# Total VAEP Value : 0.0024892482615541667
# Player ID : 9236
# Total VAEP Value : 0.002983527345350012
# Player ID : 16352
# Total VAEP Value : 0.0017750132537912577
# Player ID : 23910
# Total VAEP Value : 0.002401163219474256
# Player ID : 30681
# Total VAEP Value : -0.0038072742900112644
# Player ID : 32450
# Total VAEP Value : 0.00022385711781680584
# Player ID : 44955
# Total VAEP Value : 0.018665860901819542
# Player ID : 105943
# Total VAEP Value : 0.00292843442002777
# Player ID : 105944
# Total VAEP Value : 0.0030092309025349095
# Player ID : 128793
# Total VAEP Value : -0.0001610125764273107
# Player ID : 24475
# Total VAEP Value : 0.016807378924568184
# Player ID : 2941
# Total VAEP Value : -0.8470169051342732
# Player ID : 3404
# Total VAEP Value : 0.0721389925256517
# Player ID : 3436
# Total VAEP Value : 0.013547965241741622
# Player ID : 4506
# Total VAEP Value : 0.035557705916289706
# Player ID : 5675
# Total VAEP Value : 1.1801645040868607
# Player ID : 7379
# Total VAEP Value : 0.9784995897643967
# Player ID : 8553
# Total VAEP Value : 1.0248295328237873
# Player ID : 15970
# Total VAEP Value : 0.018773126117594074
# Player ID : 20611
# Total VAEP Value : 0.7760044144233689
# Player ID : 21026
# Total VAEP Value : -0.06129287209478207
# Player ID : 31751
# Total VAEP Value : 0.007002888243732741
# Player ID : 32915
# Total VAEP Value : 0.33809431090412545
# Player ID : 80484
# Total VAEP Value : 0.9480336444539716
# Player ID : 88123
# Total VAEP Value : 0.03209426342800725
# Player ID : 12583
# Total VAEP Value : -0.86066541193577
# Player ID : 24085
# Total VAEP Value : 0.08452842556653195
# Player ID : 28559
# Total VAEP Value : 0.1967380424394155
# Player ID : 30111
# Total VAEP Value : -0.031593413805239834
# Player ID : 31152
# Total VAEP Value : 0.026879461838689167
# Player ID : 34396
# Total VAEP Value : 0.10992550779155863
# Player ID : 36148
# Total VAEP Value : 0.9529888510987803
# Player ID : 37522
# Total VAEP Value : 0.03222838935107575
# Player ID : 37726
# Total VAEP Value : 0.11126303905984969
# Player ID : 37737
# Total VAEP Value : 0.07892334543794277
# Player ID : 37945
# Total VAEP Value : 0.001114917340601096
# Player ID : 38004
# Total VAEP Value : 0.0696489959354949
# Player ID : 40211
# Total VAEP Value : 0.02675674461715971
# Player ID : 51969
# Total VAEP Value : 0.016110737982671708
# Player ID : 91090
# Total VAEP Value : -0.0005809764479636215
# Player ID : 2988
# Total VAEP Value : 1.0443795338032942
# Player ID : 3306
# Total VAEP Value : 1.3164955467877917
# Player ID : 3311
# Total VAEP Value : 0.9416230320707655
# Player ID : 3669
# Total VAEP Value : -0.8290333892073017
# Player ID : 6994
# Total VAEP Value : 0.014437794678087812
# Player ID : 7745
# Total VAEP Value : 0.20948540712290697
# Player ID : 7829
# Total VAEP Value : 0.22323749543468285
# Player ID : 7891
# Total VAEP Value : -0.6462466188231469
# Player ID : 8118
# Total VAEP Value : 2.9584914619313167
# Player ID : 8125
# Total VAEP Value : 0.8497299992204717
# Player ID : 8259
# Total VAEP Value : 0.054603619886620436
# Player ID : 8326
# Total VAEP Value : -0.11354163587384392
# Player ID : 20033
# Total VAEP Value : -1.6512816166095714
# Player ID : 20750
# Total VAEP Value : 0.11445798137719976
# Player ID : 21547
# Total VAEP Value : -0.00818215099570807
# Player ID : 21809
# Total VAEP Value : 0.2917525422053586
# Player ID : 2995
# Total VAEP Value : 0.9722477976970367
# Player ID : 7161
# Total VAEP Value : 0.0465981122397352
# Player ID : 16308
# Total VAEP Value : -0.5474667760999627
# Player ID : 3083
# Total VAEP Value : 1.115988078173359
# Player ID : 5604
# Total VAEP Value : 1.0180824846311225
# Player ID : 5618
# Total VAEP Value : 0.04390790238176123
# Player ID : 5623
# Total VAEP Value : 0.000421704864493222
# Player ID : 22740
# Total VAEP Value : 0.0222606224269839
# Player ID : 23763
# Total VAEP Value : 0.04384761101891854
# Player ID : 29966
# Total VAEP Value : -0.02058757474878803
# Player ID : 37641
# Total VAEP Value : 0.04438382399166585
# Player ID : 40538
# Total VAEP Value : 0.046841290499287425
# Player ID : 40542
# Total VAEP Value : 0.054734326279685774
# Player ID : 40558
# Total VAEP Value : 0.008499784966261359
# Player ID : 40672
# Total VAEP Value : 0.014851947849820135
# Player ID : 41711
# Total VAEP Value : 0.18088806909509003
# Player ID : 43565
# Total VAEP Value : 0.9810890641647347
# Player ID : 4319
# Total VAEP Value : 0.007217645224955049
# Player ID : 5246
# Total VAEP Value : 0.008438617900537793
# Player ID : 5248
# Total VAEP Value : 0.0
# Player ID : 5249
# Total VAEP Value : 0.002548480453697266
# Player ID : 5255
# Total VAEP Value : 0.0007023164434940554
# Player ID : 5259
# Total VAEP Value : 0.8520583168501616
# Player ID : 5260
# Total VAEP Value : 0.021326433765352704
# Player ID : 5264
# Total VAEP Value : 0.02066330693924101
# Player ID : 6773
# Total VAEP Value : 0.10758975351927802
# Player ID : 7104
# Total VAEP Value : 0.015203856813968741
# Player ID : 28729
# Total VAEP Value : 0.0014905509451637045
# Player ID : 32478
# Total VAEP Value : 0.05247801655787043
# Player ID : 34476
# Total VAEP Value : 0.010661667554813903
# Player ID : 36288
# Total VAEP Value : 0.023949249036377296
# Player ID : 36710
# Total VAEP Value : -0.0045715392734564375
# Player ID : 3193
# Total VAEP Value : 2.1826020490134397
# Player ID : 5204
# Total VAEP Value : 1.975517993484596
# Player ID : 5206
# Total VAEP Value : 0.09501888954491733
# Player ID : 5207
# Total VAEP Value : 0.23214264424134445
# Player ID : 5209
# Total VAEP Value : 0.0795512947233874
# Player ID : 7005
# Total VAEP Value : 1.8730631342368724
# Player ID : 9927
# Total VAEP Value : 0.9571966804433032
# Player ID : 10868
# Total VAEP Value : 0.023983461030638864
# Player ID : 11184
# Total VAEP Value : 0.06938996070857684
# Player ID : 12041
# Total VAEP Value : 1.2745743861296432
# Player ID : 16028
# Total VAEP Value : 0.0096193085773848
# Player ID : 18360
# Total VAEP Value : 0.043103122960928886
# Player ID : 20016
# Total VAEP Value : 0.08058169892046863
# Player ID : 32975
# Total VAEP Value : 0.10266162033440196
# Player ID : 34639
# Total VAEP Value : 0.05039096493055695
# Player ID : 38803
# Total VAEP Value : 1.008973096133559
# Player ID : 3625
# Total VAEP Value : -0.10084203732185415
# Player ID : 5219
# Total VAEP Value : 0.037487961780243495
# Player ID : 5234
# Total VAEP Value : -0.003845756706141401
# Player ID : 5237
# Total VAEP Value : -0.14243935459487556
# Player ID : 5245
# Total VAEP Value : -0.8268901822411631
# Player ID : 6301
# Total VAEP Value : 0.8803922483912174
# Player ID : 6785
# Total VAEP Value : -0.01233648844572599
# Player ID : 7459
# Total VAEP Value : 0.00925932833342813
# Player ID : 21736
# Total VAEP Value : 0.06865321613804554
# Player ID : 23774
# Total VAEP Value : 0.015125981057281024
# Player ID : 31295
# Total VAEP Value : 0.047036383584782016
# Player ID : 46258
# Total VAEP Value : 1.1161087700729695
# Player ID : 67700
# Total VAEP Value : -0.1848669946175273
# Player ID : 102668
# Total VAEP Value : 0.002694804919883609
# Player ID : 139016
# Total VAEP Value : 0.046669169430970214
# Player ID : 296254
# Total VAEP Value : -0.0019002485842065653
# Player ID : 2972
# Total VAEP Value : 0.05178126415694351
# Player ID : 3009
# Total VAEP Value : 0.9074320082309684
# Player ID : 3026
# Total VAEP Value : 1.214383020648711
# Player ID : 3099
# Total VAEP Value : 0.04237265521533118
# Player ID : 3604
# Total VAEP Value : 0.9999293116616172
# Player ID : 4445
# Total VAEP Value : 1.4560414397506065
# Player ID : 5477
# Total VAEP Value : 1.109027139184036
# Player ID : 5485
# Total VAEP Value : 0.1092147173471858
# Player ID : 5487
# Total VAEP Value : 1.0168182578850065
# Player ID : 6704
# Total VAEP Value : 0.9193138828013616
# Player ID : 7439
# Total VAEP Value : -0.013704130731639452
# Player ID : 8217
# Total VAEP Value : -0.6743279350211874
# Player ID : 8519
# Total VAEP Value : -0.46475305239709996
# Player ID : 10481
# Total VAEP Value : 0.9592385990186134
# Player ID : 11135
# Total VAEP Value : 0.22260701101549785
# Player ID : 11990
# Total VAEP Value : 1.9104087618043195
# Player ID : 22097
# Total VAEP Value : -0.7236889167633985
# Player ID : 24778
# Total VAEP Value : 0.05549285113920632
# Player ID : 5743
# Total VAEP Value : -0.7898042570450111
# Player ID : 5187
# Total VAEP Value : -0.6172675620436844
# Player ID : 5188
# Total VAEP Value : 0.010328138632758055
# Player ID : 5713
# Total VAEP Value : 0.9064730627751487
# Player ID : 5714
# Total VAEP Value : 0.049798891252066824
# Player ID : 5715
# Total VAEP Value : -0.008614357089754776
# Player ID : 51094
# Total VAEP Value : 0.04679516325813893
# Player ID : 51096
# Total VAEP Value : -0.0015493975915887859
# Player ID : 51099
# Total VAEP Value : 0.9929159362800419
# Player ID : 51103
# Total VAEP Value : 0.004904073037323542
# Player ID : 51469
# Total VAEP Value : -0.08499559768824838
# Player ID : 51470
# Total VAEP Value : 0.11946004462151905
# Player ID : 51546
# Total VAEP Value : 0.009718145154693048
# Player ID : 51705
# Total VAEP Value : 0.021950768794340547
# Player ID : 51710
# Total VAEP Value : 0.23933023095924
# Player ID : 57620
# Total VAEP Value : 0.0029516564518417
# Player ID : 5567
# Total VAEP Value : -0.006607665367482696
# Player ID : 5568
# Total VAEP Value : 0.05618723778025014
# Player ID : 5571
# Total VAEP Value : 0.47466800585971214
# Player ID : 5573
# Total VAEP Value : 0.021237481398202362
# Player ID : 5576
# Total VAEP Value : 0.0024173679794330383
# Player ID : 5577
# Total VAEP Value : 0.012727333532893681
# Player ID : 15452
# Total VAEP Value : 0.8262739388082991
# Player ID : 26280
# Total VAEP Value : 0.003651386439742055
# Player ID : 26297
# Total VAEP Value : -0.004969863286532927
# Player ID : 26301
# Total VAEP Value : -0.0027945104320679093
# Player ID : 26318
# Total VAEP Value : 0.0028968580154469237
# Player ID : 26368
# Total VAEP Value : -0.0029831365445716074
# Player ID : 26400
# Total VAEP Value : 0.015790447370818583
# Player ID : 26406
# Total VAEP Value : 0.003264707769631059
# Player ID : 28825
# Total VAEP Value : 0.9850779256303213
# Player ID : 30500
# Total VAEP Value : 0.001276145161682507
# Player ID : 28637
# Total VAEP Value : 0.0050404020948917605
# Player ID : 3034
# Total VAEP Value : 0.006382091143677826
# Player ID : 3637
# Total VAEP Value : 0.056324884651985485
# Player ID : 4685
# Total VAEP Value : 0.000989701959042577
# Player ID : 4734
# Total VAEP Value : 0.20845135158015182
# Player ID : 5660
# Total VAEP Value : 0.020906864261633018
# Player ID : 5668
# Total VAEP Value : -0.4145219042110957
# Player ID : 5669
# Total VAEP Value : 0.03993659776460845
# Player ID : 5673
# Total VAEP Value : -0.015844309695239644
# Player ID : 7979
# Total VAEP Value : 0.03735737947681628
# Player ID : 8714
# Total VAEP Value : -0.0009270891205233056
# Player ID : 8836
# Total VAEP Value : -0.0008470813627354801
# Player ID : 11737
# Total VAEP Value : 0.9929157674614544
# Player ID : 12493
# Total VAEP Value : -0.015701037460530642
# Player ID : 28453
# Total VAEP Value : -0.0014830146865278948
# Player ID : 31955
# Total VAEP Value : -0.0008560069763916545
# Player ID : 44166
# Total VAEP Value : 0.038877769158716546
# Player ID : 7097
# Total VAEP Value : 0.02373999021074269
# Player ID : 17043
# Total VAEP Value : -0.007044687246889225
# Player ID : 26404
# Total VAEP Value : -0.0032710203995520715
# Player ID : 5563
# Total VAEP Value : 0.0011311324124108069
# Player ID : 5575
# Total VAEP Value : 0.0033558935356268194
# Player ID : 11388
# Total VAEP Value : 0.010450049601786304
# Player ID : 15872
# Total VAEP Value : 0.0027968528083874844
# Player ID : 26375
# Total VAEP Value : 0.02854626064799959
# Player ID : 11183
# Total VAEP Value : 0.0008224061748478562
# Player ID : 13620
# Total VAEP Value : 0.02911331046379928
# Player ID : 25142
# Total VAEP Value : 0.004621138141374104
# Player ID : 5543
# Total VAEP Value : -0.0047588631732651265
# Player ID : 5550
# Total VAEP Value : 1.0079779655516177
# Player ID : 8561
# Total VAEP Value : 0.0033707046968629584
# Player ID : 8814
# Total VAEP Value : 0.6491358124185354
# Player ID : 12326
# Total VAEP Value : 0.0031090737102204002
# Player ID : 16016
# Total VAEP Value : -0.001830476445320528
# Player ID : 50436
# Total VAEP Value : -0.0005048733946750872
# Player ID : 3264
# Total VAEP Value : -0.0018639994432305684
# Player ID : 4318
# Total VAEP Value : 1.7009774491343705
# Player ID : 21879
# Total VAEP Value : 0.0009133820676652249
# Player ID : 40784
# Total VAEP Value : 0.019545933515473735
# Player ID : 124488
# Total VAEP Value : 0.0765784975974384
# Player ID : 124490
# Total VAEP Value : 0.00023784780569258146
# Player ID : 124492
# Total VAEP Value : -0.10188791210202908
# Player ID : 124493
# Total VAEP Value : 1.022201406180102
# Player ID : 124494
# Total VAEP Value : 0.07261541352636414
# Player ID : 124495
# Total VAEP Value : 0.01819887822784949
# Player ID : 124500
# Total VAEP Value : 0.008679568376464886
# Player ID : 124506
# Total VAEP Value : 0.007166524339481839
# Player ID : 124510
# Total VAEP Value : 0.10431400631750876
# Player ID : 124512
# Total VAEP Value : 8.766657265368849e-05
# Player ID : 124514
# Total VAEP Value : 0.05000978757198027
# Player ID : 124899
# Total VAEP Value : -0.008506060185027309
# Player ID : 124900
# Total VAEP Value : 0.020159805366347427
# Player ID : 124901
# Total VAEP Value : 0.039044531775289215
# Player ID : 149463
# Total VAEP Value : 0.005188146556974971
# Player ID : 5214
# Total VAEP Value : -0.01259477890926064
# Player ID : 29012
# Total VAEP Value : 0.012346633080596803
# Player ID : 41655
# Total VAEP Value : -0.01420978880560142
# Player ID : 3675
# Total VAEP Value : 0.04084231157321483
# Player ID : 13314
# Total VAEP Value : -0.013593420633696951
# Player ID : 20758
# Total VAEP Value : 0.018933309949716204
# Player ID : 50498
# Total VAEP Value : -0.0015306830100598745
# Player ID : 3205
# Total VAEP Value : 0.9622619610945549
# Player ID : 3244
# Total VAEP Value : 1.8847338694831706
# Player ID : 3318
# Total VAEP Value : 0.9410882363426936
# Player ID : 3336
# Total VAEP Value : 1.9014521037388477
# Player ID : 3382
# Total VAEP Value : 2.165923236956587
# Player ID : 3468
# Total VAEP Value : 0.9279254532884806
# Player ID : 3532
# Total VAEP Value : 0.0407927923151874
# Player ID : 3943
# Total VAEP Value : 0.09244533455148485
# Player ID : 4354
# Total VAEP Value : 0.9216938699300954
# Player ID : 4706
# Total VAEP Value : 0.01003379969188245
# Player ID : 7843
# Total VAEP Value : 0.14865611559980607
# Player ID : 9638
# Total VAEP Value : -0.046868356730556116
# Player ID : 10955
# Total VAEP Value : -0.533903512778078
# Player ID : 10956
# Total VAEP Value : 0.9295623514644831
# Player ID : 22084
# Total VAEP Value : 0.12015178652836767
# Player ID : 30714
# Total VAEP Value : 0.6630055869463831
# Player ID : 3441
# Total VAEP Value : -2.246450018197674
# Player ID : 5456
# ...
# Player ID : 5690
# Total VAEP Value : 0.006522842687445518
# Player ID : 8361
# Total VAEP Value : 0.4038363602121535
# Player ID : 8776
# Total VAEP Value : -0.8716523536204245
# Player ID : 8949
# Total VAEP Value : -0.6668587729409178
# Player ID : 9411
# Total VAEP Value : 0.9960277442369261
# Player ID : 23527
# Total VAEP Value : 0.42203133424300177
# Player ID : 23721
# Total VAEP Value : 0.34647167020011693
# Player ID : 23730
# Total VAEP Value : 0.03547457723834668
# Player ID : 25719
# Total VAEP Value : -0.0953025408416579
# Player ID : 30628
# Total VAEP Value : 0.015454198878614989
# Player ID : 37208
# Total VAEP Value : 0.16768576860522444
# Player ID : 37211
# Total VAEP Value : -0.8498009251306707
# Player ID : 37215
# Total VAEP Value : 0.05164429414526239
# Player ID : 37221
# Total VAEP Value : 0.11048572840445559
# Player ID : 11127
# Total VAEP Value : -0.0015900624603091273
# Player ID : 4324
# Total VAEP Value : -0.014334928391690482
# Player ID : 11493
# Total VAEP Value : -0.05469787309266394
# Player ID : 25101
# Total VAEP Value : 0.0007742157049506204
# Player ID : 5620
# Total VAEP Value : -0.012780852136529575
# Player ID : 5986
# Total VAEP Value : 0.054661230660713045
# Player ID : 23264
# Total VAEP Value : 0.015722761186225398
# Player ID : 4626
# Total VAEP Value : 0.012617987224075478
# Player ID : 4664
# Total VAEP Value : -0.00044533928303280845
# Player ID : 5665
# Total VAEP Value : -0.17080909598007565
# Player ID : 5667
# Total VAEP Value : 0.007451249402947724
# Player ID : 50502
# Total VAEP Value : 0.0002931808412540704
# Player ID : 8069
# Total VAEP Value : 0.08823468864284223
# Player ID : 39167
# Total VAEP Value : 0.010286582582921255
# Player ID : 3377
# Total VAEP Value : 0.02620997359190369
# Player ID : 3658
# Total VAEP Value : 0.2979764678275387
# Player ID : 4614
# Total VAEP Value : 0.09176464792835759
# Player ID : 8246
# Total VAEP Value : 0.029700335489906138
# Player ID : 8526
# Total VAEP Value : -0.026750701736091287
# Player ID : 12352
# Total VAEP Value : 0.0466839414111746
# Player ID : 12524
# Total VAEP Value : 0.942566689924206
# Player ID : 12751
# Total VAEP Value : 0.9340242861617298
# Player ID : 18242
# Total VAEP Value : 0.005978844261335325
# Player ID : 21881
# Total VAEP Value : -0.06566153513085737
# Player ID : 22008
# Total VAEP Value : 0.0328273769991938
# Player ID : 22433
# Total VAEP Value : 0.26886597621341934
# Player ID : 23789
# Total VAEP Value : 0.002171878128137905
# Player ID : 24243
# Total VAEP Value : 0.007154164231906179
# Player ID : 34339
# Total VAEP Value : 0.005804319211165421
# Player ID : 38792
# Total VAEP Value : 0.11346765018970473
# Player ID : 12169
# Total VAEP Value : -0.02425025578668283
# Player ID : 40874
# Total VAEP Value : 0.02780995363536931
# Player ID : 41092
# Total VAEP Value : -0.0016930353940551868
# Player ID : 5258
# Total VAEP Value : 0.8600250648814836
# Player ID : 6297
# Total VAEP Value : 0.005264305324089946
# Player ID : 6300
# Total VAEP Value : -0.01704168906326231
# Player ID : 3053
# Total VAEP Value : 0.0707933649628103
# Player ID : 3167
# Total VAEP Value : 0.01838256141581951
# Player ID : 5562
# Total VAEP Value : 0.0011474822367745219
# Player ID : 5570
# Total VAEP Value : 0.12525124682906608
# Player ID : 5579
# Total VAEP Value : 1.3900190339900291
# Player ID : 6322
# Total VAEP Value : 0.971050029066646
# Player ID : 6324
# Total VAEP Value : 0.026141079475564766
# Player ID : 8400
# Total VAEP Value : -0.022538232449733187
# Player ID : 8507
# Total VAEP Value : 0.881864338854939
# Player ID : 8511
# Total VAEP Value : 0.0006020885848556645
# Player ID : 8546
# Total VAEP Value : 1.0302994261874119
# Player ID : 8804
# Total VAEP Value : 0.002457249001963646
# Player ID : 10287
# Total VAEP Value : 0.09132952826441898
# Player ID : 12034
# Total VAEP Value : -0.003198162508851965
# Player ID : 24118
# Total VAEP Value : 0.09307743023600779
# Player ID : 39565
# Total VAEP Value : 0.11993278658428608
# Player ID : 5199
# Total VAEP Value : 0.04148603578687471
# Player ID : 5721
# Total VAEP Value : 0.8462821560660814
# Player ID : 3141
# Total VAEP Value : 0.09718187803628098
# Player ID : 3499
# Total VAEP Value : -0.00854690126652713
# Player ID : 3551
# Total VAEP Value : 0.9795091929281625
# Player ID : 3639
# Total VAEP Value : 0.0008197859478968894
# Player ID : 4935
# Total VAEP Value : 0.022281130171904806
# Player ID : 7426
# Total VAEP Value : 0.02808644198012189
# Player ID : 7472
# Total VAEP Value : 0.03497057448112173
# Player ID : 8591
# Total VAEP Value : -0.0026781489177665208
# Player ID : 11174
# Total VAEP Value : -0.06005020321572374
# Player ID : 12623
# Total VAEP Value : 0.02082512545894133
# Player ID : 13454
# Total VAEP Value : 0.8966733582201414
# Player ID : 15326
# Total VAEP Value : 0.03215961175010307
# Player ID : 16346
# Total VAEP Value : -0.005813339810629259
# Player ID : 28966
# Total VAEP Value : -0.0017692132969386876
# Player ID : 30016
# Total VAEP Value : 0.01564439142748597
# Player ID : 46903
# Total VAEP Value : -0.004817865090444684
# Player ID : 3512
# Total VAEP Value : -0.0007714112070971169
# Player ID : 10477
# Total VAEP Value : 0.005634912606183207
# Player ID : 18737
# Total VAEP Value : -0.000550423659660737
# Player ID : 29595
# Total VAEP Value : 0.050883184139820514
# Player ID : 37122
# Total VAEP Value : 0.004767637467011809
# Player ID : 37209
# Total VAEP Value : 0.0013151913444744423
# Player ID : 38285
# Total VAEP Value : 0.006709523826430086
# Player ID : 95272
# Total VAEP Value : 0.39596469091338804
# Player ID : 5581
# Total VAEP Value : 0.7141940760348007
# Player ID : 5582
# Total VAEP Value : 0.24510906453542702
# Player ID : 5597
# Total VAEP Value : 0.1481205687232432
# Player ID : 5598
# Total VAEP Value : 0.030883824214470224
# Player ID : 5600
# Total VAEP Value : 0.01605467426998075
# Player ID : 5836
# Total VAEP Value : 0.02839312635569513
# Player ID : 5839
# Total VAEP Value : 0.5921376593214518
# Player ID : 6328
# Total VAEP Value : 0.03734180996980285
# Player ID : 108340
# Total VAEP Value : 0.00033614203675824683
# Player ID : 130185
# Total VAEP Value : 0.17776948173923302
# Player ID : 132296
# Total VAEP Value : -0.0064076715607370716
# Player ID : 132497
# Total VAEP Value : 0.001029629449476488
# Player ID : 132728
# Total VAEP Value : 0.028087941449484788
# Player ID : 132756
# Total VAEP Value : -0.009945636953489156
# Player ID : 132772
# Total VAEP Value : -2.8752721846103668e-05
# Player ID : 2954
# Total VAEP Value : 0.004359799288067734
# Player ID : 3077
# Total VAEP Value : -0.8678161639400059
# Player ID : 3089
# Total VAEP Value : 0.9160356884840439
# Player ID : 3176
# Total VAEP Value : 0.019520450914569665
# Player ID : 3289
# Total VAEP Value : -0.026065043231938034
# Player ID : 3457
# Total VAEP Value : -0.025030512506418745
# Player ID : 3509
# Total VAEP Value : 0.0805450102307077
# Player ID : 3621
# Total VAEP Value : 0.006545572146933409
# Player ID : 5630
# Total VAEP Value : 0.00203336104277696
# Player ID : 5632
# Total VAEP Value : -0.007090296438946098
# Player ID : 5642
# Total VAEP Value : 0.0694230335066095
# Player ID : 6989
# Total VAEP Value : -0.0033219283850485226
# Player ID : 16559
# Total VAEP Value : -0.009296686530433362
# Player ID : 20005
# Total VAEP Value : 0.1492069734431425
# Player ID : 32688
# Total VAEP Value : 0.00021195588851696812
# Player ID : 48347
# Total VAEP Value : 0.004086635317435139
# Player ID : 5233
# Total VAEP Value : 0.017694914204184897
# Player ID : 8227
# Total VAEP Value : 0.020977353771741036
# Player ID : 8966
# Total VAEP Value : 1.0135320530080207
# Player ID : 38837
# Total VAEP Value : -0.01912296657974366
# Player ID : 31090
# Total VAEP Value : 0.030948801275371807
# Player ID : 3086
# Total VAEP Value : -0.07879565713301417
# Player ID : 3488
# Total VAEP Value : -0.000255990176810883
# Player ID : 3517
# Total VAEP Value : 0.015280734143743757
# Player ID : 3853
# Total VAEP Value : 0.021803285595524358
# Player ID : 4767
# Total VAEP Value : -0.007781059139233548
# Player ID : 4774
# Total VAEP Value : -0.05722276621236233
# Player ID : 4934
# Total VAEP Value : 0.01986095280153677
# Player ID : 6399
# Total VAEP Value : 0.16146845666846776
# Player ID : 9540
# Total VAEP Value : 0.0076345377492543776
# Player ID : 11250
# Total VAEP Value : -0.10425170612870716
# Player ID : 11252
# Total VAEP Value : 0.010122910818608943
# Player ID : 22074
# Total VAEP Value : 0.012636243889573961
# Player ID : 29377
# Total VAEP Value : 0.8625808083525044
# Player ID : 34794
# Total VAEP Value : 0.2685171518842253
# Player ID : 50528
# Total VAEP Value : 0.0013806561764795333
# Player ID : 13035
# Total VAEP Value : 0.0022439475942519493
# Player ID : 22168
# Total VAEP Value : 0.02881080528459279
# Player ID : 12803
# Total VAEP Value : 0.023026172128084
# Player ID : 23830
# Total VAEP Value : 1.14599126527537
# Player ID : 348757
# Total VAEP Value : 0.0002557859697844833
# Player ID : 124496
# Total VAEP Value : -0.0011599012177612167
# Player ID : 124503
# Total VAEP Value : 0.027112506304547423
# Player ID : 124909
# Total VAEP Value : -0.002720482436416205
# Player ID : 124504
# Total VAEP Value : 0.006095668773923535
# Player ID : 5178
# Total VAEP Value : -0.0011582075039768824
# Player ID : 5183
# Total VAEP Value : 0.025722491091983102
# Player ID : 5191
# Total VAEP Value : -0.0039521503349533305
# Player ID : 54144
# Total VAEP Value : 0.22544401054619811
# Player ID : 56755
# Total VAEP Value : 0.35752070620583254
# Player ID : 121539
# Total VAEP Value : -6.607241630263161e-05
# Player ID : 2989
# Total VAEP Value : -0.011268603211647132
# Player ID : 3347
# Total VAEP Value : -0.5407223354177172
# Player ID : 3450
# Total VAEP Value : -0.8375767774759879
# Player ID : 3709
# Total VAEP Value : 0.9742145437066938
# Player ID : 6383
# Total VAEP Value : 0.10486897400369344
# Player ID : 6393
# Total VAEP Value : 0.06917813439122256
# Player ID : 8108
# Total VAEP Value : 0.01098028138767404
# Player ID : 12259
# Total VAEP Value : -0.00011137173714814708
# Player ID : 12325
# Total VAEP Value : 0.974908123228488
# Player ID : 17033
# Total VAEP Value : 0.12222397773530247
# Player ID : 23615
# Total VAEP Value : -0.04856498471417581
# Player ID : 28616
# Total VAEP Value : 0.01614178210911632
# Player ID : 30519
# Total VAEP Value : 1.0848838744695968
# Player ID : 31029
# Total VAEP Value : -0.41548633400179824
# Player ID : 33602
# Total VAEP Value : 0.15642214304898516
# Player ID : 35658
# Total VAEP Value : 0.008395707634917926
# Player ID : 3135
# Total VAEP Value : 0.0020737302147608716
# Player ID : 22067
# Total VAEP Value : -0.0039920599629112985
# Player ID : 40564
# Total VAEP Value : -0.0060419425249165215
# Player ID : 9286
# Total VAEP Value : 0.005589661232079379
# Player ID : 44225
# Total VAEP Value : -0.013175565705751069
# Player ID : 45047
# Total VAEP Value : 0.010810339164891047
# Player ID : 4272
# Total VAEP Value : -0.0017109152122429805
# Player ID : 13621
# Total VAEP Value : 0.06317704711818806
# Player ID : 51632
# Total VAEP Value : -0.0002314255980309099
# Player ID : 74623
# Total VAEP Value : -0.0062110721482895315
# Player ID : 5633
# Total VAEP Value : 0.0001312008243985474
# Player ID : 6331
# Total VAEP Value : 0.011325325147481635
# Player ID : 23650
# Total VAEP Value : 0.0
# Player ID : 136306
# Total VAEP Value : 0.00027476728428155184
# Player ID : 36666
# Total VAEP Value : 0.0018977730360347778
# Player ID : 8808
# Total VAEP Value : 0.0017208926874445751
# Player ID : 5595
# Total VAEP Value : 0.0014599436763091944
# Player ID : 15477
# Total VAEP Value : 0.030067603497627715
# Player ID : 27163
# Total VAEP Value : 0.009714047005218163
# Player ID : 135271
# Total VAEP Value : -0.0008629803487565368
# Player ID : 3957
# Total VAEP Value : 0.8286445744233788
# Player ID : 5592
# Total VAEP Value : 0.006960138074646238
# Player ID : 132271
# Total VAEP Value : -0.027279638710751897
# Player ID : 184468
# Total VAEP Value : 0.0014018570400367025
# Player ID : 8064
# Total VAEP Value : 0.004076090932358056
# Player ID : 16015
# Total VAEP Value : -0.0014335680025396869
# Player ID : 3684
# Total VAEP Value : -0.010940095766272862
# Player ID : 50497
# Total VAEP Value : 0.01658796184347011
# Player ID : 9922
# Total VAEP Value : 0.02969945811855723
# Player ID : 11187
# Total VAEP Value : 0.0018099890021403553
# Player ID : 11846
# Total VAEP Value : 0.007192716668214416
# Player ID : 12365
# Total VAEP Value : -0.7037202624887636
# Player ID : 12770
# Total VAEP Value : -1.6253109885910817
# Player ID : 15958
# Total VAEP Value : 0.08861577354400652
# Player ID : 16120
# Total VAEP Value : -0.0020878228915535146
# Player ID : 16459
# Total VAEP Value : -0.010408720205305144
# Player ID : 23640
# Total VAEP Value : 0.025255679018300725
# Player ID : 23828
# Total VAEP Value : 0.016361880306249077
# Player ID : 24024
# Total VAEP Value : 0.8797454018676945
# Player ID : 26348
# Total VAEP Value : 0.001447665403247811
# Player ID : 29758
# Total VAEP Value : -0.09122669776297698
# Player ID : 31684
# Total VAEP Value : 0.0057221530623792205
# Player ID : 44703
# Total VAEP Value : 0.008473334253721987
# Player ID : 133229
# Total VAEP Value : -0.04276644175479305
# Player ID : 3067
# Total VAEP Value : -0.004754908521135803
# Player ID : 3247
# Total VAEP Value : 0.02459120076673571
# Player ID : 25154
# Total VAEP Value : -0.004782994212291669
# Player ID : 7551
# Total VAEP Value : -0.0063696103388792835
# Player ID : 10530
# Total VAEP Value : -0.021256859057757538
# Player ID : 33813
# Total VAEP Value : -0.12446180530969286
# Player ID : 74588
# Total VAEP Value : 0.0023823215014999732
# Player ID : 5476
# Total VAEP Value : 0.045334476217249176
# Player ID : 5484
# Total VAEP Value : -0.00026010921283159405
# Player ID : 9430
# Total VAEP Value : 0.006777751914341934
# Player ID : 33572
# Total VAEP Value : 0.37194317401372246
# Player ID : 6806
# Total VAEP Value : 0.0057556812826078385
# Player ID : 15971
# Total VAEP Value : 0.00255557620403124
# Player ID : 5220
# Total VAEP Value : -0.824876382957882
# Player ID : 5224
# Total VAEP Value : 0.012891974783997284
# Player ID : 5226
# Total VAEP Value : 0.5286161675885755
# Player ID : 5227
# Total VAEP Value : 0.002656954435224179
# Player ID : 5228
# Total VAEP Value : -0.04211477975513844
# Player ID : 5230
# Total VAEP Value : 0.028129711577093985
# Player ID : 5231
# Total VAEP Value : -0.0014435010889428668
# Player ID : 5235
# Total VAEP Value : -0.03470105990709271
# Player ID : 5240
# Total VAEP Value : 0.011646668979665264
# Player ID : 5720
# Total VAEP Value : 0.008134219848216162
# Player ID : 5722
# Total VAEP Value : 0.013313633868165198
# Player ID : 23874
# Total VAEP Value : 0.028813332133722724
# Player ID : 124161
# Total VAEP Value : 0.9517070531946956
# Player ID : 124167
# Total VAEP Value : 0.06038960531986959
# Player ID : 125818
# Total VAEP Value : -0.031272639927919954
# Player ID : 326758
# Total VAEP Value : 0.003964494506362826
# Player ID : 9036
# Total VAEP Value : -0.00012459349818527699
# Player ID : 16252
# Total VAEP Value : -0.07230762668132229
# Player ID : 3543
# Total VAEP Value : 0.003703513168147765
# Player ID : 7153
# Total VAEP Value : -0.001945525815244764
# Player ID : 7345
# Total VAEP Value : 0.0009720299713080749
# Player ID : 17592
# Total VAEP Value : 0.00530536517908331
# Player ID : 5647
# Total VAEP Value : -0.0045139064459363
# Player ID : 6347
# Total VAEP Value : -0.0031948852993082255
# Player ID : 25582
# Total VAEP Value : 0.012687587775872089
# Player ID : 35592
# Total VAEP Value : 0.004204656041110866
# Player ID : 102816
# Total VAEP Value : 0.0027786240680143237
# Player ID : 9914
# Total VAEP Value : -0.7086477403936442
# Player ID : 10931
# Total VAEP Value : 0.0049468500474176835
# Player ID : 5222
# Total VAEP Value : 0.801231350236776
# Player ID : 5239
# Total VAEP Value : 0.8927120775279036
# Player ID : 125823
# Total VAEP Value : -1.8443292984647996
# Player ID : 3308
# Total VAEP Value : -0.005485018567014777
# Player ID : 3616
# Total VAEP Value : 0.021818063185492065
# Player ID : 23538
# Total VAEP Value : 1.0258117256944388
# Player ID : 124175
# Total VAEP Value : -0.023866687934059883
# Player ID : 16275
# Total VAEP Value : -0.0008444876584690064
# Player ID : 23363
# Total VAEP Value : 0.00046374376688618213
# Player ID : 99479
# Total VAEP Value : 0
# Player ID : 5218
# Total VAEP Value : -0.03659396668535919
# Player ID : 143854
# Total VAEP Value : -0.017060030542779714
# Player ID : 82257
# Total VAEP Value : 0.005876554525457323
# Player ID : 3664
# Total VAEP Value : 0.01546841420349665
# Player ID : 6892
# Total VAEP Value : -0.5551731102877966
# Player ID : 5527
# Total VAEP Value : 0.0
# Player ID : 5534
# Total VAEP Value : 0.0
# Player ID : 50988
# Total VAEP Value : 0.0
# =================================================================

# %%
def export_players_vaep_final_ranking_per_competition():
    final_player_skills_dataset = pd.read_csv(DIRECTORY_FINAL_PLAYERS_CSV_DATAS)
    for competition_id, season_id in list(MAPS_PLAYER_ID_WITH_VAEP_VALUE.keys()):
        list_player_ids_this_competition = list(MAPS_PLAYER_ID_WITH_VAEP_VALUE[(competition_id, season_id)].keys())
        player_datas_this_competition = final_player_skills_dataset[final_player_skills_dataset['player_id'].isin(list_player_ids_this_competition)]
        player_datas_this_competition['statistic_minutes_played'] = np.zeros(player_datas_this_competition.shape[0])
        player_datas_this_competition['statistic_vaep_value'] = np.zeros(player_datas_this_competition.shape[0])
        player_datas_this_competition['statistic_rating_vaep_value'] = np.zeros(player_datas_this_competition.shape[0])
        for player_id in list_player_ids_this_competition:
            num_minutes_played = MAPS_PLAYER_ID_WITH_VAEP_VALUE[(competition_id, season_id)][player_id]['num_minutes_played']
            total_vaep_value = MAPS_PLAYER_ID_WITH_VAEP_VALUE[(competition_id, season_id)][player_id]['total_vaep_value']
            statistic_rating_vaep_value = 0 if (num_minutes_played == 0) or (total_vaep_value == 0) else (90 / num_minutes_played) * total_vaep_value

            player_datas_this_competition.loc[player_datas_this_competition['player_id'] == player_id, ['statistic_minutes_played']] \
                = num_minutes_played
            player_datas_this_competition.loc[player_datas_this_competition['player_id'] == player_id, ['statistic_vaep_value']] \
                = total_vaep_value
            player_datas_this_competition.loc[player_datas_this_competition['player_id'] == player_id, ['statistic_rating_vaep_value']] \
                = statistic_rating_vaep_value
                
        player_datas_this_competition.sort_values(by="statistic_rating_vaep_value", ascending=False, inplace=True)
        player_datas_this_competition.reset_index(drop=True, inplace=True)
        filename_vaep_ranking_this_competition = f'vaep_players_ranking_for_competition_{MAPS_COMPETITION_CONTAINS_360_DATA[(competition_id, season_id)]}.csv'
        player_datas_this_competition.to_csv(DIRECTORY_PLAYERS_DATA + filename_vaep_ranking_this_competition)

# %%
# COMMENT IT IF VAEP PLAYER RANKING ALREADY LOADED
export_players_vaep_final_ranking_per_competition()

# %%
# Construct dataframe containing competition name and related event id 
COLUMNS_COMPETITION_NAME_AND_EVENT_ID_RESULT = [
    "competition_id",
    "season_id",
    "competition_name",
    "event_id_related"
]

def construct_df_containing_competition_name_and_event_id():
    for competition_id, season_id in list(MAPS_COMPETITION_CONTAINS_360_DATA.keys()):
        games_df = api.games(competition_id, season_id)
        competition_name = MAPS_COMPETITION_CONTAINS_360_DATA[(competition_id, season_id)]
        list_game_events_df = []
        for _, row in games_df.iterrows():
            this_game_events_df = api.events(row['game_id'], load_360=True)
            this_game_events_df = spadl.add_names(convert_to_actions_statsbomb(this_game_events_df, row['home_team_id']))
            list_game_events_df.append(this_game_events_df)
        all_games_df_this_competition = pd.concat(list_game_events_df)
        for key in list(MAPS_PROPOSED_PLAYER_RANKING_GENERATOR.keys()):
            list_type_ids = MAPS_PROPOSED_PLAYER_RANKING_GENERATOR[key]['type_ids_spadl']
            model_directory = MAPS_PROPOSED_PLAYER_RANKING_GENERATOR[key]['model_directory']
            all_games_df_this_type = all_games_df_this_competition[all_games_df_this_competition['type_id'].isin(list_type_ids)]
            unique_original_event_ids = all_games_df_this_type['original_event_id'].unique()

            empty_df_result = pd.DataFrame(columns=COLUMNS_COMPETITION_NAME_AND_EVENT_ID_RESULT, index=[0])
            for event_id in unique_original_event_ids:
                maps_new_row = {
                    "competition_id" : competition_id,
                    "season_id" : season_id,
                    "competition_name" : competition_name,
                    "event_id_related" : event_id
                }  
                new_row = pd.DataFrame(maps_new_row, index=[0])
                empty_df_result = pd.concat([new_row, empty_df_result.loc[:]]).reset_index(drop=True)
            empty_df_result.dropna(inplace=True)
            filename_result = f'{key}_map_competition_and_event_id_for_{competition_name}.csv'
            empty_df_result.to_csv(model_directory + filename_result)

# %%
# COMMENT IT IF ALREADY CONSTRUCTED !!
# construct_df_containing_competition_name_and_event_id()

# %%
def construct_final_ranking_players_proposed_method():
    final_player_skills_dataset = pd.read_csv(DIRECTORY_FINAL_PLAYERS_CSV_DATAS)
    for scenario_opt in POSSIBLE_SCENARIO_OPTION:
        for competition_id, season_id in list(MAPS_PLAYER_ID_WITH_VAEP_VALUE.keys()):
            competition_name = MAPS_COMPETITION_CONTAINS_360_DATA[(competition_id, season_id)]
            list_player_ids_this_competition = list(MAPS_PLAYER_ID_WITH_VAEP_VALUE[(competition_id, season_id)].keys())
            for key in list(MAPS_PROPOSED_PLAYER_RANKING_GENERATOR.keys()):
                action_name = MAPS_PROPOSED_PLAYER_RANKING_GENERATOR[key]["action_name"]
                model_directory = MAPS_PROPOSED_PLAYER_RANKING_GENERATOR[key]["model_directory"]
                filename_ranking_this_directory = f'{key}_contribution_score_player_{scenario_opt}_scenario_{competition_name}.csv'
                player_score_contributions_df = pd.read_csv(model_directory + filename_ranking_this_directory)
                for player_id in list_player_ids_this_competition:
                    this_player_score_df = player_score_contributions_df.loc[player_score_contributions_df['player_id'] == player_id, [f'statistic_{action_name}_contribution']]
                    if (not this_player_score_df.empty):
                        MAPS_PLAYER_ID_WITH_VAEP_VALUE[(competition_id, season_id)][player_id]["total_contribution_score"] += this_player_score_df[f'statistic_{action_name}_contribution'].iloc[0]
            
            player_datas_this_competition = final_player_skills_dataset[final_player_skills_dataset['player_id'].isin(list_player_ids_this_competition)]
            player_datas_this_competition['statistic_minutes_played'] = np.zeros(player_datas_this_competition.shape[0])
            player_datas_this_competition['statistic_contribution_value'] = np.zeros(player_datas_this_competition.shape[0])
            for player_id in list_player_ids_this_competition:
                num_minutes_played = MAPS_PLAYER_ID_WITH_VAEP_VALUE[(competition_id, season_id)][player_id]['num_minutes_played']
                total_contribution_value = MAPS_PLAYER_ID_WITH_VAEP_VALUE[(competition_id, season_id)][player_id]['total_contribution_score']
                statistic_rating_contribution_value = 0 if (num_minutes_played == 0) or (total_contribution_value == 0) else (90 / num_minutes_played) * total_contribution_value

                player_datas_this_competition.loc[player_datas_this_competition['player_id'] == player_id, ['statistic_minutes_played']] \
                    = num_minutes_played
                player_datas_this_competition.loc[player_datas_this_competition['player_id'] == player_id, ['statistic_contribution_value']] \
                    = total_contribution_value
                player_datas_this_competition.loc[player_datas_this_competition['player_id'] == player_id, ['statistic_rating_contribution_value']] \
                    = statistic_rating_contribution_value
                    
            player_datas_this_competition.sort_values(by="statistic_rating_contribution_value", ascending=False, inplace=True)
            player_datas_this_competition.reset_index(drop=True, inplace=True)
            filename_vaep_ranking_this_competition = f'proposed_players_ranking_{scenario_opt}_scenario_for_competition_{competition_name}.csv'
            player_datas_this_competition.to_csv(DIRECTORY_PLAYERS_DATA + filename_vaep_ranking_this_competition)

# %%
# COMMENT IT IF ALREADY CONSTRUCTED !!
# construct_final_ranking_players_proposed_method()
